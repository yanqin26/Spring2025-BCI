# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
import numpy as np


import os
import json
import pyarrow.parquet as pq
import pyarrow as pa
from datasets import Dataset, DatasetDict, concatenate_datasets
from datasets import Features, Value
from datasets import  load_dataset, DownloadConfig
from datasets import load_from_disk
import pandas as pd



from utils.data_loaders import BiBci2000MELR_filter, BiBci2000MELR
from models.bi_lstm import BiLSTMEncoder, ToyClassifier
from huggingface_hub import hf_hub_download
from huggingface_hub import snapshot_download
from PyEMD import CEEMDAN, EMD
import torch.nn.functional as F

# %%
# 超参数
BATCH_SIZE = 24
EPOCHS = 200
LEARNING_RATE = 0.0001
HIDDEN_SIZE = 50
NUM_LAYERS = 2
NUM_CLASSES = 1  # 二分类任务
INPUT_SIZE = 656  
SEQ_LENGTH = 64

# %%
print(torch.cuda.is_available())  
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# True
# cuda

# %%
train_path = "D:\\EEG25_Data\\BCI2000_cls9\\sliced\\train"
test_path = "D:\\EEG25_Data\\BCI2000_cls9\\sliced\\test"

# 列出文件夹中的所有文件
train_files = os.listdir(train_path)
test_files = os.listdir(test_path)

# 筛选出所有的PT文件
train_files = [f for f in train_files if f.endswith('.pt')]
test_files = [f for f in test_files if f.endswith('.pt')]

# 初始化存储列表
train_data_list = []
train_label_list = []
test_data_list = []
test_label_list = []

# 处理测试集
index = 0
for pt_file in test_files:
    file_path = os.path.join(test_path, pt_file)
    try:
        data = torch.load(file_path)
        
        # 检查第二个维度长度
        if data.shape[1] < 640:
            print(f"跳过测试文件 {pt_file}，第二维度长度 {data.shape[1]} < 640")
            continue
            
        # 处理标签
        label = pt_file.split("_")[-1]
        label = label[3]  # 假设文件名格式为 XXX_clsX.pt
        test_label_list.append(int(label))  # 转换为整数
        
        # 处理数据
        data = data[:, :640]
        test_data_list.append(data)
        
    except Exception as e:
        print(f"加载测试文件 {pt_file} 失败: {str(e)}")
    
    index += 1
    print(f"测试集处理进度: {index/len(test_files):.2%}")

# 处理训练集
index = 0
for pt_file in train_files:
    file_path = os.path.join(train_path, pt_file)
    try:
        data = torch.load(file_path)
        
        # 检查第二个维度长度
        if data.shape[1] < 640:
            print(f"跳过训练文件 {pt_file}，第二维度长度 {data.shape[1]} < 640")
            continue
            
        # 处理标签
        label = pt_file.split("_")[-1]
        label = label[3]  # 假设文件名格式为 XXX_clsX.pt
        train_label_list.append(int(label))  # 转换为整数
        
        # 处理数据
        data = data[:, :640]
        train_data_list.append(data)
        
    except Exception as e:
        print(f"加载训练文件 {pt_file} 失败: {str(e)}")
    
    index += 1
    print(f"训练集处理进度: {index/len(train_files):.2%}")

# 最终统计信息
print("\n处理结果统计:")
print(f"有效测试样本数: {len(test_data_list)}/{len(test_files)}")
print(f"有效训练样本数: {len(train_data_list)}/{len(train_files)}")
# Out:
# 测试集处理进度: 0.01%
# 测试集处理进度: 0.02%
# 测试集处理进度: 0.03%
# 测试集处理进度: 0.03%
# 测试集处理进度: 0.04%
# 测试集处理进度: 0.05%
# 测试集处理进度: 0.06%
# 测试集处理进度: 0.07%
# 测试集处理进度: 0.08%
# 测试集处理进度: 0.09%
# 测试集处理进度: 0.09%
# 测试集处理进度: 0.10%
# 测试集处理进度: 0.11%
# 测试集处理进度: 0.12%
# 测试集处理进度: 0.13%
# 测试集处理进度: 0.14%
# 测试集处理进度: 0.14%
# 测试集处理进度: 0.15%
# 测试集处理进度: 0.16%
# 测试集处理进度: 0.17%
# 测试集处理进度: 0.18%
# 测试集处理进度: 0.19%
# 测试集处理进度: 0.20%
# 测试集处理进度: 0.20%
# 测试集处理进度: 0.21%
# 测试集处理进度: 0.22%
# 测试集处理进度: 0.23%
# 测试集处理进度: 0.24%
# 测试集处理进度: 0.25%
# 测试集处理进度: 0.26%
# 测试集处理进度: 0.26%
# 测试集处理进度: 0.27%
# 测试集处理进度: 0.28%
# 测试集处理进度: 0.29%
# 测试集处理进度: 0.30%
# 测试集处理进度: 0.31%
# 测试集处理进度: 0.32%
# 测试集处理进度: 0.32%
# 测试集处理进度: 0.33%
# 测试集处理进度: 0.34%
# 测试集处理进度: 0.35%
# 测试集处理进度: 0.36%
# 测试集处理进度: 0.37%
# 测试集处理进度: 0.37%
# 测试集处理进度: 0.38%
# 测试集处理进度: 0.39%
# 测试集处理进度: 0.40%
# 测试集处理进度: 0.41%
# 测试集处理进度: 0.42%
# 测试集处理进度: 0.43%
# 测试集处理进度: 0.43%
# 测试集处理进度: 0.44%
# 测试集处理进度: 0.45%
# 测试集处理进度: 0.46%
# 测试集处理进度: 0.47%
# 测试集处理进度: 0.48%
# 测试集处理进度: 0.49%
# 测试集处理进度: 0.49%
# 测试集处理进度: 0.50%
# 测试集处理进度: 0.51%
# 测试集处理进度: 0.52%
# 测试集处理进度: 0.53%
# 测试集处理进度: 0.54%
# 测试集处理进度: 0.55%
# 测试集处理进度: 0.55%
# 测试集处理进度: 0.56%
# 测试集处理进度: 0.57%
# 测试集处理进度: 0.58%
# 测试集处理进度: 0.59%
# 测试集处理进度: 0.60%
# 测试集处理进度: 0.60%
# 测试集处理进度: 0.61%
# 测试集处理进度: 0.62%
# 测试集处理进度: 0.63%
# 测试集处理进度: 0.64%
# 测试集处理进度: 0.65%
# 测试集处理进度: 0.66%
# 测试集处理进度: 0.66%
# 测试集处理进度: 0.67%
# 测试集处理进度: 0.68%
# 测试集处理进度: 0.69%
# 测试集处理进度: 0.70%
# 测试集处理进度: 0.71%
# 测试集处理进度: 0.72%
# 测试集处理进度: 0.72%
# 测试集处理进度: 0.73%
# 测试集处理进度: 0.74%
# 测试集处理进度: 0.75%
# 测试集处理进度: 0.76%
# 测试集处理进度: 0.77%
# 测试集处理进度: 0.78%
# 测试集处理进度: 0.78%
# 测试集处理进度: 0.79%
# 测试集处理进度: 0.80%
# 测试集处理进度: 0.81%
# 测试集处理进度: 0.82%
# 测试集处理进度: 0.83%
# 测试集处理进度: 0.83%
# 测试集处理进度: 0.84%
# 测试集处理进度: 0.85%
# 测试集处理进度: 0.86%
# 测试集处理进度: 0.87%
# 测试集处理进度: 0.88%
# 测试集处理进度: 0.89%
# 测试集处理进度: 0.89%
# 测试集处理进度: 0.90%
# 测试集处理进度: 0.91%
# 测试集处理进度: 0.92%
# 测试集处理进度: 0.93%
# 测试集处理进度: 0.94%
# 测试集处理进度: 0.95%
# 测试集处理进度: 0.95%
# 测试集处理进度: 0.96%
# 测试集处理进度: 0.97%
# 测试集处理进度: 0.98%
# 测试集处理进度: 0.99%
# 测试集处理进度: 1.00%
# 测试集处理进度: 1.01%
# 测试集处理进度: 1.01%
# 测试集处理进度: 1.02%
# 测试集处理进度: 1.03%
# 测试集处理进度: 1.04%
# 测试集处理进度: 1.05%
# 测试集处理进度: 1.06%
# 测试集处理进度: 1.06%
# 测试集处理进度: 1.07%
# 测试集处理进度: 1.08%
# 测试集处理进度: 1.09%
# 测试集处理进度: 1.10%
# 测试集处理进度: 1.11%
# 测试集处理进度: 1.12%
# 测试集处理进度: 1.12%
# 测试集处理进度: 1.13%
# 测试集处理进度: 1.14%
# 测试集处理进度: 1.15%
# 测试集处理进度: 1.16%
# 测试集处理进度: 1.17%
# 测试集处理进度: 1.18%
# 测试集处理进度: 1.18%
# 测试集处理进度: 1.19%
# 测试集处理进度: 1.20%
# 测试集处理进度: 1.21%
# 测试集处理进度: 1.22%
# 测试集处理进度: 1.23%
# 测试集处理进度: 1.23%
# 测试集处理进度: 1.24%
# 测试集处理进度: 1.25%
# 测试集处理进度: 1.26%
# 测试集处理进度: 1.27%
# 测试集处理进度: 1.28%
# 测试集处理进度: 1.29%
# 测试集处理进度: 1.29%
# 测试集处理进度: 1.30%
# 测试集处理进度: 1.31%
# 测试集处理进度: 1.32%
# 测试集处理进度: 1.33%
# 测试集处理进度: 1.34%
# 测试集处理进度: 1.35%
# 测试集处理进度: 1.35%
# 测试集处理进度: 1.36%
# 测试集处理进度: 1.37%
# 测试集处理进度: 1.38%
# 测试集处理进度: 1.39%
# 测试集处理进度: 1.40%
# 测试集处理进度: 1.41%
# 测试集处理进度: 1.41%
# 测试集处理进度: 1.42%
# 测试集处理进度: 1.43%
# 测试集处理进度: 1.44%
# 测试集处理进度: 1.45%
# 测试集处理进度: 1.46%
# 测试集处理进度: 1.46%
# 测试集处理进度: 1.47%
# 测试集处理进度: 1.48%
# 测试集处理进度: 1.49%
# 测试集处理进度: 1.50%
# 测试集处理进度: 1.51%
# 测试集处理进度: 1.52%
# 测试集处理进度: 1.52%
# 测试集处理进度: 1.53%
# 测试集处理进度: 1.54%
# 测试集处理进度: 1.55%
# 测试集处理进度: 1.56%
# 测试集处理进度: 1.57%
# 测试集处理进度: 1.58%
# 测试集处理进度: 1.58%
# 测试集处理进度: 1.59%
# 测试集处理进度: 1.60%
# 测试集处理进度: 1.61%
# 测试集处理进度: 1.62%
# 测试集处理进度: 1.63%
# 测试集处理进度: 1.64%
# 测试集处理进度: 1.64%
# 测试集处理进度: 1.65%
# 测试集处理进度: 1.66%
# 测试集处理进度: 1.67%
# 测试集处理进度: 1.68%
# 测试集处理进度: 1.69%
# 测试集处理进度: 1.69%
# 测试集处理进度: 1.70%
# 测试集处理进度: 1.71%
# 测试集处理进度: 1.72%
# 测试集处理进度: 1.73%
# 测试集处理进度: 1.74%
# 测试集处理进度: 1.75%
# 测试集处理进度: 1.75%
# 测试集处理进度: 1.76%
# 测试集处理进度: 1.77%
# 测试集处理进度: 1.78%
# 测试集处理进度: 1.79%
# 测试集处理进度: 1.80%
# 测试集处理进度: 1.81%
# 测试集处理进度: 1.81%
# 测试集处理进度: 1.82%
# 测试集处理进度: 1.83%
# 测试集处理进度: 1.84%
# 测试集处理进度: 1.85%
# 测试集处理进度: 1.86%
# 测试集处理进度: 1.87%
# 测试集处理进度: 1.87%
# 测试集处理进度: 1.88%
# 测试集处理进度: 1.89%
# 测试集处理进度: 1.90%
# 测试集处理进度: 1.91%
# 测试集处理进度: 1.92%
# 测试集处理进度: 1.92%
# 测试集处理进度: 1.93%
# 测试集处理进度: 1.94%
# 测试集处理进度: 1.95%
# 测试集处理进度: 1.96%
# 测试集处理进度: 1.97%
# 测试集处理进度: 1.98%
# 测试集处理进度: 1.98%
# 测试集处理进度: 1.99%
# 测试集处理进度: 2.00%
# 测试集处理进度: 2.01%
# 测试集处理进度: 2.02%
# 测试集处理进度: 2.03%
# 测试集处理进度: 2.04%
# 测试集处理进度: 2.04%
# 测试集处理进度: 2.05%
# 测试集处理进度: 2.06%
# 测试集处理进度: 2.07%
# 测试集处理进度: 2.08%
# 测试集处理进度: 2.09%
# 测试集处理进度: 2.10%
# 测试集处理进度: 2.10%
# 测试集处理进度: 2.11%
# 测试集处理进度: 2.12%
# 测试集处理进度: 2.13%
# 测试集处理进度: 2.14%
# 测试集处理进度: 2.15%
# 测试集处理进度: 2.15%
# 测试集处理进度: 2.16%
# 测试集处理进度: 2.17%
# 测试集处理进度: 2.18%
# 测试集处理进度: 2.19%
# 测试集处理进度: 2.20%
# 测试集处理进度: 2.21%
# 测试集处理进度: 2.21%
# 测试集处理进度: 2.22%
# 测试集处理进度: 2.23%
# 测试集处理进度: 2.24%
# 测试集处理进度: 2.25%
# 测试集处理进度: 2.26%
# 测试集处理进度: 2.27%
# 测试集处理进度: 2.27%
# 测试集处理进度: 2.28%
# 测试集处理进度: 2.29%
# 测试集处理进度: 2.30%
# 测试集处理进度: 2.31%
# 测试集处理进度: 2.32%
# 测试集处理进度: 2.33%
# 测试集处理进度: 2.33%
# 测试集处理进度: 2.34%
# 测试集处理进度: 2.35%
# 测试集处理进度: 2.36%
# 测试集处理进度: 2.37%
# 测试集处理进度: 2.38%
# 测试集处理进度: 2.38%
# 测试集处理进度: 2.39%
# 测试集处理进度: 2.40%
# 测试集处理进度: 2.41%
# 测试集处理进度: 2.42%
# 测试集处理进度: 2.43%
# 测试集处理进度: 2.44%
# 测试集处理进度: 2.44%
# 测试集处理进度: 2.45%
# 测试集处理进度: 2.46%
# 测试集处理进度: 2.47%
# 测试集处理进度: 2.48%
# 测试集处理进度: 2.49%
# 测试集处理进度: 2.50%
# 测试集处理进度: 2.50%
# 测试集处理进度: 2.51%
# 测试集处理进度: 2.52%
# 测试集处理进度: 2.53%
# 测试集处理进度: 2.54%
# 测试集处理进度: 2.55%
# 测试集处理进度: 2.56%
# 测试集处理进度: 2.56%
# 测试集处理进度: 2.57%
# 测试集处理进度: 2.58%
# 测试集处理进度: 2.59%
# 测试集处理进度: 2.60%
# 测试集处理进度: 2.61%
# 测试集处理进度: 2.61%
# 测试集处理进度: 2.62%
# 测试集处理进度: 2.63%
# 测试集处理进度: 2.64%
# 测试集处理进度: 2.65%
# 测试集处理进度: 2.66%
# 测试集处理进度: 2.67%
# 测试集处理进度: 2.67%
# 测试集处理进度: 2.68%
# 测试集处理进度: 2.69%
# 测试集处理进度: 2.70%
# 测试集处理进度: 2.71%
# 测试集处理进度: 2.72%
# 测试集处理进度: 2.73%
# 测试集处理进度: 2.73%
# 测试集处理进度: 2.74%
# 测试集处理进度: 2.75%
# 测试集处理进度: 2.76%
# 测试集处理进度: 2.77%
# 测试集处理进度: 2.78%
# 测试集处理进度: 2.79%
# 测试集处理进度: 2.79%
# 测试集处理进度: 2.80%
# 测试集处理进度: 2.81%
# 测试集处理进度: 2.82%
# 测试集处理进度: 2.83%
# 测试集处理进度: 2.84%
# 测试集处理进度: 2.84%
# 测试集处理进度: 2.85%
# 测试集处理进度: 2.86%
# 测试集处理进度: 2.87%
# 测试集处理进度: 2.88%
# 测试集处理进度: 2.89%
# 测试集处理进度: 2.90%
# 测试集处理进度: 2.90%
# 测试集处理进度: 2.91%
# 测试集处理进度: 2.92%
# 测试集处理进度: 2.93%
# 测试集处理进度: 2.94%
# 测试集处理进度: 2.95%
# 测试集处理进度: 2.96%
# 测试集处理进度: 2.96%
# 测试集处理进度: 2.97%
# 测试集处理进度: 2.98%
# 测试集处理进度: 2.99%
# 测试集处理进度: 3.00%
# 测试集处理进度: 3.01%
# 测试集处理进度: 3.02%
# 测试集处理进度: 3.02%
# 测试集处理进度: 3.03%
# 测试集处理进度: 3.04%
# 测试集处理进度: 3.05%
# 测试集处理进度: 3.06%
# 测试集处理进度: 3.07%
# 测试集处理进度: 3.07%
# 测试集处理进度: 3.08%
# 测试集处理进度: 3.09%
# 测试集处理进度: 3.10%
# 测试集处理进度: 3.11%
# 测试集处理进度: 3.12%
# 测试集处理进度: 3.13%
# 测试集处理进度: 3.13%
# 测试集处理进度: 3.14%
# 测试集处理进度: 3.15%
# 测试集处理进度: 3.16%
# 测试集处理进度: 3.17%
# 测试集处理进度: 3.18%
# 测试集处理进度: 3.19%
# 测试集处理进度: 3.19%
# 测试集处理进度: 3.20%
# 测试集处理进度: 3.21%
# 测试集处理进度: 3.22%
# 测试集处理进度: 3.23%
# 测试集处理进度: 3.24%
# 测试集处理进度: 3.25%
# 测试集处理进度: 3.25%
# 测试集处理进度: 3.26%
# 测试集处理进度: 3.27%
# 测试集处理进度: 3.28%
# 测试集处理进度: 3.29%
# 测试集处理进度: 3.30%
# 测试集处理进度: 3.30%
# C:\Users\ChenYiqiao\AppData\Local\Temp\ipykernel_27264\132860326.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(file_path)
# 测试集处理进度: 3.31%
# 测试集处理进度: 3.32%
# 测试集处理进度: 3.33%
# 测试集处理进度: 3.34%
# 测试集处理进度: 3.35%
# 测试集处理进度: 3.36%
# 测试集处理进度: 3.36%
# 测试集处理进度: 3.37%
# 测试集处理进度: 3.38%
# 测试集处理进度: 3.39%
# 测试集处理进度: 3.40%
# 测试集处理进度: 3.41%
# 测试集处理进度: 3.42%
# 测试集处理进度: 3.42%
# 测试集处理进度: 3.43%
# 测试集处理进度: 3.44%
# 测试集处理进度: 3.45%
# 测试集处理进度: 3.46%
# 测试集处理进度: 3.47%
# 测试集处理进度: 3.48%
# 测试集处理进度: 3.48%
# 测试集处理进度: 3.49%
# 测试集处理进度: 3.50%
# 测试集处理进度: 3.51%
# 测试集处理进度: 3.52%
# 测试集处理进度: 3.53%
# 测试集处理进度: 3.53%
# 测试集处理进度: 3.54%
# 测试集处理进度: 3.55%
# 测试集处理进度: 3.56%
# 测试集处理进度: 3.57%
# 测试集处理进度: 3.58%
# 测试集处理进度: 3.59%
# 测试集处理进度: 3.59%
# 测试集处理进度: 3.60%
# 测试集处理进度: 3.61%
# 测试集处理进度: 3.62%
# 测试集处理进度: 3.63%
# 测试集处理进度: 3.64%
# 测试集处理进度: 3.65%
# 测试集处理进度: 3.65%
# 测试集处理进度: 3.66%
# 测试集处理进度: 3.67%
# 测试集处理进度: 3.68%
# 测试集处理进度: 3.69%
# 测试集处理进度: 3.70%
# 测试集处理进度: 3.70%
# 测试集处理进度: 3.71%
# 测试集处理进度: 3.72%
# 测试集处理进度: 3.73%
# 测试集处理进度: 3.74%
# 测试集处理进度: 3.75%
# 测试集处理进度: 3.76%
# 测试集处理进度: 3.76%
# 测试集处理进度: 3.77%
# 测试集处理进度: 3.78%
# 测试集处理进度: 3.79%
# 测试集处理进度: 3.80%
# 测试集处理进度: 3.81%
# 测试集处理进度: 3.82%
# 测试集处理进度: 3.82%
# 测试集处理进度: 3.83%
# 测试集处理进度: 3.84%
# 测试集处理进度: 3.85%
# 测试集处理进度: 3.86%
# 测试集处理进度: 3.87%
# 测试集处理进度: 3.88%
# 测试集处理进度: 3.88%
# 测试集处理进度: 3.89%
# 测试集处理进度: 3.90%
# 测试集处理进度: 3.91%
# 测试集处理进度: 3.92%
# 测试集处理进度: 3.93%
# 测试集处理进度: 3.93%
# 测试集处理进度: 3.94%
# 测试集处理进度: 3.95%
# 测试集处理进度: 3.96%
# 测试集处理进度: 3.97%
# 测试集处理进度: 3.98%
# 测试集处理进度: 3.99%
# 测试集处理进度: 3.99%
# 测试集处理进度: 4.00%
# 测试集处理进度: 4.01%
# 测试集处理进度: 4.02%
# 测试集处理进度: 4.03%
# 测试集处理进度: 4.04%
# 测试集处理进度: 4.05%
# 测试集处理进度: 4.05%
# 测试集处理进度: 4.06%
# 测试集处理进度: 4.07%
# 测试集处理进度: 4.08%
# 测试集处理进度: 4.09%
# 测试集处理进度: 4.10%
# 测试集处理进度: 4.11%
# 测试集处理进度: 4.11%
# 测试集处理进度: 4.12%
# 测试集处理进度: 4.13%
# 测试集处理进度: 4.14%
# 测试集处理进度: 4.15%
# 测试集处理进度: 4.16%
# 测试集处理进度: 4.16%
# 测试集处理进度: 4.17%
# 测试集处理进度: 4.18%
# 测试集处理进度: 4.19%
# 测试集处理进度: 4.20%
# 测试集处理进度: 4.21%
# 测试集处理进度: 4.22%
# 测试集处理进度: 4.22%
# 测试集处理进度: 4.23%
# 测试集处理进度: 4.24%
# 测试集处理进度: 4.25%
# 测试集处理进度: 4.26%
# 测试集处理进度: 4.27%
# 测试集处理进度: 4.28%
# 测试集处理进度: 4.28%
# 测试集处理进度: 4.29%
# 测试集处理进度: 4.30%
# 测试集处理进度: 4.31%
# 测试集处理进度: 4.32%
# 测试集处理进度: 4.33%
# 测试集处理进度: 4.34%
# 测试集处理进度: 4.34%
# 测试集处理进度: 4.35%
# 测试集处理进度: 4.36%
# 测试集处理进度: 4.37%
# 测试集处理进度: 4.38%
# 测试集处理进度: 4.39%
# 测试集处理进度: 4.39%
# 测试集处理进度: 4.40%
# 测试集处理进度: 4.41%
# 测试集处理进度: 4.42%
# 测试集处理进度: 4.43%
# 测试集处理进度: 4.44%
# 测试集处理进度: 4.45%
# 测试集处理进度: 4.45%
# 测试集处理进度: 4.46%
# 测试集处理进度: 4.47%
# 测试集处理进度: 4.48%
# 测试集处理进度: 4.49%
# 测试集处理进度: 4.50%
# 测试集处理进度: 4.51%
# 测试集处理进度: 4.51%
# 测试集处理进度: 4.52%
# 测试集处理进度: 4.53%
# 测试集处理进度: 4.54%
# 测试集处理进度: 4.55%
# 测试集处理进度: 4.56%
# 测试集处理进度: 4.57%
# 测试集处理进度: 4.57%
# 测试集处理进度: 4.58%
# 测试集处理进度: 4.59%
# 测试集处理进度: 4.60%
# 测试集处理进度: 4.61%
# 测试集处理进度: 4.62%
# 测试集处理进度: 4.62%
# 测试集处理进度: 4.63%
# 测试集处理进度: 4.64%
# 测试集处理进度: 4.65%
# 测试集处理进度: 4.66%
# 测试集处理进度: 4.67%
# 测试集处理进度: 4.68%
# 测试集处理进度: 4.68%
# 测试集处理进度: 4.69%
# 测试集处理进度: 4.70%
# 测试集处理进度: 4.71%
# 测试集处理进度: 4.72%
# 测试集处理进度: 4.73%
# 测试集处理进度: 4.74%
# 测试集处理进度: 4.74%
# 测试集处理进度: 4.75%
# 测试集处理进度: 4.76%
# 测试集处理进度: 4.77%
# 测试集处理进度: 4.78%
# 测试集处理进度: 4.79%
# 测试集处理进度: 4.80%
# 测试集处理进度: 4.80%
# 测试集处理进度: 4.81%
# 测试集处理进度: 4.82%
# 测试集处理进度: 4.83%
# 测试集处理进度: 4.84%
# 测试集处理进度: 4.85%
# 测试集处理进度: 4.85%
# 测试集处理进度: 4.86%
# 测试集处理进度: 4.87%
# 测试集处理进度: 4.88%
# 测试集处理进度: 4.89%
# 测试集处理进度: 4.90%
# 测试集处理进度: 4.91%
# 测试集处理进度: 4.91%
# 测试集处理进度: 4.92%
# 测试集处理进度: 4.93%
# 测试集处理进度: 4.94%
# 测试集处理进度: 4.95%
# 测试集处理进度: 4.96%
# 测试集处理进度: 4.97%
# 测试集处理进度: 4.97%
# 测试集处理进度: 4.98%
# 测试集处理进度: 4.99%
# 测试集处理进度: 5.00%
# 测试集处理进度: 5.01%
# 测试集处理进度: 5.02%
# 测试集处理进度: 5.03%
# 测试集处理进度: 5.03%
# 测试集处理进度: 5.04%
# 测试集处理进度: 5.05%
# 测试集处理进度: 5.06%
# 测试集处理进度: 5.07%
# 测试集处理进度: 5.08%
# 测试集处理进度: 5.08%
# 测试集处理进度: 5.09%
# 测试集处理进度: 5.10%
# 测试集处理进度: 5.11%
# 测试集处理进度: 5.12%
# 测试集处理进度: 5.13%
# 测试集处理进度: 5.14%
# 测试集处理进度: 5.14%
# 测试集处理进度: 5.15%
# 测试集处理进度: 5.16%
# 测试集处理进度: 5.17%
# 测试集处理进度: 5.18%
# 测试集处理进度: 5.19%
# 测试集处理进度: 5.20%
# 测试集处理进度: 5.20%
# 测试集处理进度: 5.21%
# 测试集处理进度: 5.22%
# 测试集处理进度: 5.23%
# 测试集处理进度: 5.24%
# 测试集处理进度: 5.25%
# 测试集处理进度: 5.26%
# 测试集处理进度: 5.26%
# 测试集处理进度: 5.27%
# 测试集处理进度: 5.28%
# 测试集处理进度: 5.29%
# 测试集处理进度: 5.30%
# 测试集处理进度: 5.31%
# 测试集处理进度: 5.31%
# 测试集处理进度: 5.32%
# 测试集处理进度: 5.33%
# 测试集处理进度: 5.34%
# 测试集处理进度: 5.35%
# 测试集处理进度: 5.36%
# 测试集处理进度: 5.37%
# 测试集处理进度: 5.37%
# 测试集处理进度: 5.38%
# 测试集处理进度: 5.39%
# 测试集处理进度: 5.40%
# 测试集处理进度: 5.41%
# 测试集处理进度: 5.42%
# 测试集处理进度: 5.43%
# 测试集处理进度: 5.43%
# 测试集处理进度: 5.44%
# 测试集处理进度: 5.45%
# 测试集处理进度: 5.46%
# 测试集处理进度: 5.47%
# 测试集处理进度: 5.48%
# 测试集处理进度: 5.49%
# 测试集处理进度: 5.49%
# 测试集处理进度: 5.50%
# 测试集处理进度: 5.51%
# 测试集处理进度: 5.52%
# 测试集处理进度: 5.53%
# 测试集处理进度: 5.54%
# 测试集处理进度: 5.54%
# 测试集处理进度: 5.55%
# 测试集处理进度: 5.56%
# 测试集处理进度: 5.57%
# 测试集处理进度: 5.58%
# 测试集处理进度: 5.59%
# 测试集处理进度: 5.60%
# 测试集处理进度: 5.60%
# 测试集处理进度: 5.61%
# 测试集处理进度: 5.62%
# 测试集处理进度: 5.63%
# 测试集处理进度: 5.64%
# 测试集处理进度: 5.65%
# 测试集处理进度: 5.66%
# 测试集处理进度: 5.66%
# 测试集处理进度: 5.67%
# 测试集处理进度: 5.68%
# 测试集处理进度: 5.69%
# 测试集处理进度: 5.70%
# 测试集处理进度: 5.71%
# 测试集处理进度: 5.72%
# 测试集处理进度: 5.72%
# 测试集处理进度: 5.73%
# 测试集处理进度: 5.74%
# 测试集处理进度: 5.75%
# 测试集处理进度: 5.76%
# 测试集处理进度: 5.77%
# 测试集处理进度: 5.77%
# 测试集处理进度: 5.78%
# 测试集处理进度: 5.79%
# 测试集处理进度: 5.80%
# 测试集处理进度: 5.81%
# 测试集处理进度: 5.82%
# 测试集处理进度: 5.83%
# 测试集处理进度: 5.83%
# 测试集处理进度: 5.84%
# 测试集处理进度: 5.85%
# 测试集处理进度: 5.86%
# 测试集处理进度: 5.87%
# 测试集处理进度: 5.88%
# 测试集处理进度: 5.89%
# 测试集处理进度: 5.89%
# 测试集处理进度: 5.90%
# 测试集处理进度: 5.91%
# 测试集处理进度: 5.92%
# 测试集处理进度: 5.93%
# 测试集处理进度: 5.94%
# 测试集处理进度: 5.94%
# 测试集处理进度: 5.95%
# 测试集处理进度: 5.96%
# 测试集处理进度: 5.97%
# 测试集处理进度: 5.98%
# 测试集处理进度: 5.99%
# 测试集处理进度: 6.00%
# 测试集处理进度: 6.00%
# 测试集处理进度: 6.01%
# 测试集处理进度: 6.02%
# 测试集处理进度: 6.03%
# 测试集处理进度: 6.04%
# 测试集处理进度: 6.05%
# 测试集处理进度: 6.06%
# 测试集处理进度: 6.06%
# 测试集处理进度: 6.07%
# 测试集处理进度: 6.08%
# 测试集处理进度: 6.09%
# 测试集处理进度: 6.10%
# 测试集处理进度: 6.11%
# 测试集处理进度: 6.12%
# 测试集处理进度: 6.12%
# 测试集处理进度: 6.13%
# 测试集处理进度: 6.14%
# 测试集处理进度: 6.15%
# 测试集处理进度: 6.16%
# 测试集处理进度: 6.17%
# 测试集处理进度: 6.17%
# 测试集处理进度: 6.18%
# 测试集处理进度: 6.19%
# 测试集处理进度: 6.20%
# 测试集处理进度: 6.21%
# 测试集处理进度: 6.22%
# 测试集处理进度: 6.23%
# 测试集处理进度: 6.23%
# 测试集处理进度: 6.24%
# 测试集处理进度: 6.25%
# 测试集处理进度: 6.26%
# 测试集处理进度: 6.27%
# 测试集处理进度: 6.28%
# 测试集处理进度: 6.29%
# 测试集处理进度: 6.29%
# 测试集处理进度: 6.30%
# 测试集处理进度: 6.31%
# 测试集处理进度: 6.32%
# 测试集处理进度: 6.33%
# 测试集处理进度: 6.34%
# 测试集处理进度: 6.35%
# 测试集处理进度: 6.35%
# 测试集处理进度: 6.36%
# 测试集处理进度: 6.37%
# 测试集处理进度: 6.38%
# 测试集处理进度: 6.39%
# 测试集处理进度: 6.40%
# 测试集处理进度: 6.40%
# 测试集处理进度: 6.41%
# 测试集处理进度: 6.42%
# 测试集处理进度: 6.43%
# 测试集处理进度: 6.44%
# 测试集处理进度: 6.45%
# 测试集处理进度: 6.46%
# 测试集处理进度: 6.46%
# 测试集处理进度: 6.47%
# 测试集处理进度: 6.48%
# 测试集处理进度: 6.49%
# 测试集处理进度: 6.50%
# 测试集处理进度: 6.51%
# 测试集处理进度: 6.52%
# 测试集处理进度: 6.52%
# 测试集处理进度: 6.53%
# 测试集处理进度: 6.54%
# 测试集处理进度: 8.17%
# 测试集处理进度: 8.18%
# 测试集处理进度: 8.18%
# 测试集处理进度: 8.19%
# 测试集处理进度: 8.20%
# 测试集处理进度: 8.21%
# 测试集处理进度: 8.22%
# 测试集处理进度: 8.23%
# 测试集处理进度: 8.24%
# 测试集处理进度: 8.24%
# 测试集处理进度: 8.25%
# 测试集处理进度: 8.26%
# 测试集处理进度: 8.27%
# 测试集处理进度: 8.28%
# 测试集处理进度: 8.29%
# 测试集处理进度: 8.30%
# 测试集处理进度: 8.30%
# 测试集处理进度: 8.31%
# 测试集处理进度: 8.32%
# 测试集处理进度: 8.33%
# 测试集处理进度: 8.34%
# 测试集处理进度: 8.35%
# 测试集处理进度: 8.36%
# 测试集处理进度: 8.36%
# 测试集处理进度: 8.37%
# 测试集处理进度: 8.38%
# 测试集处理进度: 8.39%
# 测试集处理进度: 8.40%
# 测试集处理进度: 8.41%
# 测试集处理进度: 8.41%
# 测试集处理进度: 8.42%
# 测试集处理进度: 8.43%
# 测试集处理进度: 8.44%
# 测试集处理进度: 8.45%
# 测试集处理进度: 8.46%
# 测试集处理进度: 8.47%
# 测试集处理进度: 8.47%
# 测试集处理进度: 8.48%
# 测试集处理进度: 8.49%
# 测试集处理进度: 8.50%
# 测试集处理进度: 8.51%
# 测试集处理进度: 8.52%
# 测试集处理进度: 8.53%
# 测试集处理进度: 8.53%
# 测试集处理进度: 8.54%
# 测试集处理进度: 8.55%
# 测试集处理进度: 8.56%
# 测试集处理进度: 8.57%
# 测试集处理进度: 8.58%
# 测试集处理进度: 8.59%
# 测试集处理进度: 8.59%
# 测试集处理进度: 8.60%
# 测试集处理进度: 8.61%
# 测试集处理进度: 8.62%
# 测试集处理进度: 8.63%
# 测试集处理进度: 8.64%
# 测试集处理进度: 8.64%
# 测试集处理进度: 8.65%
# 测试集处理进度: 8.66%
# 测试集处理进度: 8.67%
# 测试集处理进度: 8.68%
# 测试集处理进度: 8.69%
# 测试集处理进度: 8.70%
# 测试集处理进度: 8.70%
# 测试集处理进度: 8.71%
# 测试集处理进度: 8.72%
# 测试集处理进度: 8.73%
# 测试集处理进度: 8.74%
# 测试集处理进度: 8.75%
# 测试集处理进度: 8.76%
# 测试集处理进度: 8.76%
# 测试集处理进度: 8.77%
# 测试集处理进度: 8.78%
# 测试集处理进度: 8.79%
# 测试集处理进度: 8.80%
# 测试集处理进度: 8.81%
# 测试集处理进度: 8.82%
# 测试集处理进度: 8.82%
# 测试集处理进度: 8.83%
# 测试集处理进度: 8.84%
# 测试集处理进度: 8.85%
# 测试集处理进度: 8.86%
# 测试集处理进度: 8.87%
# 测试集处理进度: 8.87%
# 测试集处理进度: 8.88%
# 测试集处理进度: 8.89%
# 测试集处理进度: 8.90%
# 测试集处理进度: 8.91%
# 测试集处理进度: 8.92%
# 测试集处理进度: 8.93%
# 测试集处理进度: 8.93%
# 测试集处理进度: 8.94%
# 测试集处理进度: 8.95%
# 测试集处理进度: 8.96%
# 测试集处理进度: 8.97%
# 测试集处理进度: 8.98%
# 测试集处理进度: 8.99%
# 测试集处理进度: 8.99%
# 测试集处理进度: 9.00%
# 测试集处理进度: 9.01%
# 测试集处理进度: 9.02%
# 测试集处理进度: 9.03%
# 测试集处理进度: 9.04%
# 测试集处理进度: 9.05%
# 测试集处理进度: 9.05%
# 测试集处理进度: 9.06%
# 测试集处理进度: 9.07%
# 测试集处理进度: 9.08%
# 测试集处理进度: 9.09%
# 测试集处理进度: 9.10%
# 测试集处理进度: 9.10%
# 测试集处理进度: 9.11%
# 测试集处理进度: 9.12%
# 测试集处理进度: 9.13%
# 测试集处理进度: 9.14%
# 测试集处理进度: 9.15%
# 测试集处理进度: 9.16%
# 测试集处理进度: 9.16%
# 测试集处理进度: 9.17%
# 测试集处理进度: 9.18%
# 测试集处理进度: 9.19%
# 测试集处理进度: 9.20%
# 测试集处理进度: 9.21%
# 测试集处理进度: 9.22%
# 测试集处理进度: 9.22%
# 测试集处理进度: 9.23%
# 测试集处理进度: 9.24%
# 测试集处理进度: 9.25%
# 测试集处理进度: 9.26%
# 测试集处理进度: 9.27%
# 测试集处理进度: 9.28%
# 测试集处理进度: 9.28%
# 测试集处理进度: 9.29%
# 测试集处理进度: 9.30%
# 测试集处理进度: 9.31%
# 测试集处理进度: 9.32%
# 测试集处理进度: 9.33%
# 测试集处理进度: 9.33%
# 测试集处理进度: 9.34%
# 测试集处理进度: 9.35%
# 测试集处理进度: 9.36%
# 测试集处理进度: 9.37%
# 测试集处理进度: 9.38%
# 测试集处理进度: 9.39%
# 测试集处理进度: 9.39%
# 测试集处理进度: 9.40%
# 测试集处理进度: 9.41%
# 测试集处理进度: 9.42%
# 测试集处理进度: 9.43%
# 测试集处理进度: 9.44%
# 测试集处理进度: 9.45%
# 测试集处理进度: 9.45%
# 测试集处理进度: 9.46%
# 测试集处理进度: 9.47%
# 测试集处理进度: 9.48%
# 测试集处理进度: 9.49%
# 测试集处理进度: 9.50%
# 测试集处理进度: 9.51%
# 测试集处理进度: 9.51%
# 测试集处理进度: 9.52%
# 测试集处理进度: 9.53%
# 测试集处理进度: 9.54%
# 测试集处理进度: 9.55%
# 测试集处理进度: 9.56%
# 测试集处理进度: 9.56%
# 测试集处理进度: 9.57%
# 测试集处理进度: 9.58%
# 测试集处理进度: 9.59%
# 测试集处理进度: 9.60%
# 测试集处理进度: 9.61%
# 测试集处理进度: 9.62%
# 测试集处理进度: 9.62%
# 测试集处理进度: 9.63%
# 测试集处理进度: 9.64%
# 测试集处理进度: 9.65%
# 测试集处理进度: 9.66%
# 测试集处理进度: 9.67%
# 测试集处理进度: 9.68%
# 测试集处理进度: 9.68%
# 测试集处理进度: 9.69%
# 测试集处理进度: 9.70%
# 测试集处理进度: 9.71%
# 测试集处理进度: 9.72%
# 测试集处理进度: 9.73%
# 测试集处理进度: 9.74%
# 测试集处理进度: 9.74%
# 测试集处理进度: 9.75%
# 测试集处理进度: 9.76%
# 测试集处理进度: 9.77%
# 测试集处理进度: 9.78%
# 测试集处理进度: 9.79%
# 测试集处理进度: 9.79%
# 测试集处理进度: 9.80%
# 测试集处理进度: 9.81%
# 测试集处理进度: 9.82%
# 测试集处理进度: 9.83%
# 测试集处理进度: 9.84%
# 测试集处理进度: 9.85%
# 测试集处理进度: 9.85%
# 测试集处理进度: 9.86%
# 测试集处理进度: 9.87%
# 测试集处理进度: 9.88%
# 测试集处理进度: 9.89%
# 测试集处理进度: 9.90%
# 测试集处理进度: 9.91%
# 测试集处理进度: 9.91%
# 测试集处理进度: 9.92%
# 测试集处理进度: 9.93%
# 测试集处理进度: 9.94%
# 测试集处理进度: 9.95%
# 测试集处理进度: 9.96%
# 测试集处理进度: 9.97%
# 测试集处理进度: 9.97%
# 测试集处理进度: 9.98%
# 测试集处理进度: 9.99%
# 测试集处理进度: 10.00%
# 测试集处理进度: 10.01%
# 测试集处理进度: 10.02%
# 测试集处理进度: 10.02%
# 测试集处理进度: 10.03%
# 测试集处理进度: 10.04%
# 测试集处理进度: 10.05%
# 测试集处理进度: 10.06%
# 测试集处理进度: 10.07%
# 测试集处理进度: 10.08%
# 测试集处理进度: 10.08%
# 测试集处理进度: 10.09%
# 测试集处理进度: 10.10%
# 测试集处理进度: 10.11%
# 测试集处理进度: 10.12%
# 测试集处理进度: 10.13%
# 测试集处理进度: 10.14%
# 测试集处理进度: 10.14%
# 测试集处理进度: 10.15%
# 测试集处理进度: 10.16%
# 测试集处理进度: 10.17%
# 测试集处理进度: 10.18%
# 测试集处理进度: 10.19%
# 测试集处理进度: 10.20%
# 测试集处理进度: 10.20%
# 测试集处理进度: 10.21%
# 测试集处理进度: 10.22%
# 测试集处理进度: 10.23%
# 测试集处理进度: 10.24%
# 测试集处理进度: 10.25%
# 测试集处理进度: 10.25%
# 测试集处理进度: 10.26%
# 测试集处理进度: 10.27%
# 测试集处理进度: 10.28%
# 测试集处理进度: 10.29%
# 测试集处理进度: 10.30%
# 测试集处理进度: 10.31%
# 测试集处理进度: 10.31%
# 测试集处理进度: 10.32%
# 测试集处理进度: 10.33%
# 测试集处理进度: 10.34%
# 测试集处理进度: 10.35%
# 测试集处理进度: 10.36%
# 测试集处理进度: 10.37%
# 测试集处理进度: 10.37%
# 测试集处理进度: 10.38%
# 测试集处理进度: 10.39%
# 测试集处理进度: 10.40%
# 测试集处理进度: 10.41%
# 测试集处理进度: 10.42%
# 测试集处理进度: 10.43%
# 测试集处理进度: 10.43%
# 测试集处理进度: 10.44%
# 测试集处理进度: 10.45%
# 测试集处理进度: 10.46%
# 测试集处理进度: 10.47%
# 测试集处理进度: 10.48%
# 测试集处理进度: 10.48%
# 测试集处理进度: 10.49%
# 测试集处理进度: 10.50%
# 测试集处理进度: 10.51%
# 测试集处理进度: 10.52%
# 测试集处理进度: 10.53%
# 测试集处理进度: 10.54%
# 测试集处理进度: 10.54%
# 测试集处理进度: 10.55%
# 测试集处理进度: 10.56%
# 测试集处理进度: 10.57%
# 测试集处理进度: 10.58%
# 测试集处理进度: 10.59%
# 测试集处理进度: 10.60%
# 测试集处理进度: 10.60%
# 测试集处理进度: 10.61%
# 测试集处理进度: 10.62%
# 测试集处理进度: 10.63%
# 测试集处理进度: 10.64%
# 测试集处理进度: 10.65%
# 测试集处理进度: 10.65%
# 测试集处理进度: 10.66%
# 测试集处理进度: 10.67%
# 测试集处理进度: 10.68%
# 测试集处理进度: 10.69%
# 测试集处理进度: 10.70%
# 测试集处理进度: 10.71%
# 测试集处理进度: 10.71%
# 测试集处理进度: 10.72%
# 测试集处理进度: 10.73%
# 测试集处理进度: 10.74%
# 测试集处理进度: 10.75%
# 测试集处理进度: 10.76%
# 测试集处理进度: 10.77%
# 测试集处理进度: 10.77%
# 测试集处理进度: 10.78%
# 测试集处理进度: 10.79%
# 测试集处理进度: 10.80%
# 测试集处理进度: 10.81%
# 测试集处理进度: 10.82%
# 测试集处理进度: 10.83%
# 测试集处理进度: 10.83%
# 测试集处理进度: 10.84%
# 测试集处理进度: 10.85%
# 测试集处理进度: 10.86%
# 测试集处理进度: 10.87%
# 测试集处理进度: 10.88%
# 测试集处理进度: 10.88%
# 测试集处理进度: 10.89%
# 测试集处理进度: 10.90%
# 测试集处理进度: 10.91%
# 测试集处理进度: 10.92%
# 测试集处理进度: 10.93%
# 测试集处理进度: 10.94%
# 测试集处理进度: 10.94%
# 测试集处理进度: 10.95%
# 测试集处理进度: 10.96%
# 测试集处理进度: 10.97%
# 测试集处理进度: 10.98%
# 测试集处理进度: 10.99%
# 测试集处理进度: 11.00%
# 测试集处理进度: 11.00%
# 测试集处理进度: 11.01%
# 测试集处理进度: 11.02%
# 测试集处理进度: 11.03%
# 测试集处理进度: 11.04%
# 测试集处理进度: 11.05%
# 测试集处理进度: 11.06%
# 测试集处理进度: 11.06%
# 测试集处理进度: 11.07%
# 测试集处理进度: 11.08%
# 测试集处理进度: 11.09%
# 测试集处理进度: 11.10%
# 测试集处理进度: 11.11%
# 测试集处理进度: 11.11%
# 测试集处理进度: 11.12%
# 测试集处理进度: 11.13%
# 测试集处理进度: 11.14%
# 测试集处理进度: 11.15%
# 测试集处理进度: 11.16%
# 测试集处理进度: 11.17%
# 测试集处理进度: 11.17%
# 测试集处理进度: 11.18%
# 测试集处理进度: 11.19%
# 测试集处理进度: 11.20%
# 测试集处理进度: 11.21%
# 测试集处理进度: 11.22%
# 测试集处理进度: 11.23%
# 测试集处理进度: 11.23%
# 测试集处理进度: 11.24%
# 测试集处理进度: 11.25%
# 测试集处理进度: 11.26%
# 测试集处理进度: 11.27%
# 测试集处理进度: 11.28%
# 测试集处理进度: 11.29%
# 测试集处理进度: 11.29%
# 测试集处理进度: 11.30%
# 测试集处理进度: 11.31%
# 测试集处理进度: 11.32%
# 测试集处理进度: 11.33%
# 测试集处理进度: 11.34%
# 测试集处理进度: 11.34%
# 测试集处理进度: 11.35%
# 测试集处理进度: 11.36%
# 测试集处理进度: 11.37%
# 测试集处理进度: 11.38%
# 测试集处理进度: 11.39%
# 测试集处理进度: 11.40%
# 测试集处理进度: 11.40%
# 测试集处理进度: 11.41%
# 测试集处理进度: 11.42%
# 测试集处理进度: 11.43%
# 测试集处理进度: 11.44%
# 测试集处理进度: 11.45%
# 测试集处理进度: 11.46%
# 测试集处理进度: 11.46%
# 测试集处理进度: 11.47%
# 测试集处理进度: 11.48%
# 测试集处理进度: 11.49%
# 测试集处理进度: 11.50%
# 测试集处理进度: 11.51%
# 测试集处理进度: 11.52%
# 测试集处理进度: 11.52%
# 测试集处理进度: 11.53%
# 测试集处理进度: 11.54%
# 测试集处理进度: 11.55%
# 测试集处理进度: 11.56%
# 测试集处理进度: 11.57%
# 测试集处理进度: 11.57%
# 测试集处理进度: 11.58%
# 测试集处理进度: 11.59%
# 测试集处理进度: 11.60%
# 测试集处理进度: 11.61%
# 测试集处理进度: 11.62%
# 测试集处理进度: 11.63%
# 测试集处理进度: 11.63%
# 测试集处理进度: 11.64%
# 测试集处理进度: 11.65%
# 测试集处理进度: 11.66%
# 测试集处理进度: 11.67%
# 测试集处理进度: 11.68%
# 测试集处理进度: 11.69%
# 测试集处理进度: 11.69%
# 测试集处理进度: 11.70%
# 测试集处理进度: 11.71%
# 测试集处理进度: 11.72%
# 测试集处理进度: 11.73%
# 测试集处理进度: 11.74%
# 测试集处理进度: 11.75%
# 测试集处理进度: 11.75%
# 测试集处理进度: 11.76%
# 测试集处理进度: 11.77%
# 测试集处理进度: 11.78%
# 测试集处理进度: 11.79%
# 测试集处理进度: 11.80%
# 测试集处理进度: 11.80%
# 测试集处理进度: 11.81%
# 测试集处理进度: 11.82%
# 测试集处理进度: 11.83%
# 测试集处理进度: 11.84%
# 测试集处理进度: 11.85%
# 测试集处理进度: 11.86%
# 测试集处理进度: 11.86%
# 测试集处理进度: 11.87%
# 测试集处理进度: 11.88%
# 测试集处理进度: 11.89%
# 测试集处理进度: 11.90%
# 测试集处理进度: 11.91%
# 测试集处理进度: 11.92%
# 测试集处理进度: 11.92%
# 测试集处理进度: 11.93%
# 测试集处理进度: 11.94%
# 测试集处理进度: 11.95%
# 测试集处理进度: 11.96%
# 测试集处理进度: 11.97%
# 测试集处理进度: 11.98%
# 测试集处理进度: 11.98%
# 测试集处理进度: 11.99%
# 测试集处理进度: 12.00%
# 测试集处理进度: 12.01%
# 测试集处理进度: 12.02%
# 测试集处理进度: 12.03%
# 测试集处理进度: 12.03%
# 测试集处理进度: 12.04%
# 测试集处理进度: 12.05%
# 测试集处理进度: 12.06%
# 测试集处理进度: 12.07%
# 测试集处理进度: 12.08%
# 测试集处理进度: 12.09%
# 测试集处理进度: 12.09%
# 测试集处理进度: 12.10%
# 测试集处理进度: 12.11%
# 测试集处理进度: 12.12%
# 测试集处理进度: 12.13%
# 测试集处理进度: 12.14%
# 测试集处理进度: 12.15%
# 测试集处理进度: 12.15%
# 测试集处理进度: 12.16%
# 测试集处理进度: 12.17%
# 测试集处理进度: 12.18%
# 测试集处理进度: 12.19%
# 测试集处理进度: 12.20%
# 测试集处理进度: 12.21%
# 测试集处理进度: 12.21%
# 测试集处理进度: 12.22%
# 测试集处理进度: 12.23%
# 测试集处理进度: 12.24%
# 测试集处理进度: 12.25%
# 测试集处理进度: 12.26%
# 测试集处理进度: 12.26%
# 测试集处理进度: 12.27%
# 测试集处理进度: 12.28%
# 测试集处理进度: 12.29%
# 测试集处理进度: 12.30%
# 测试集处理进度: 12.31%
# 测试集处理进度: 12.32%
# 测试集处理进度: 12.32%
# 测试集处理进度: 12.33%
# 测试集处理进度: 12.34%
# 测试集处理进度: 12.35%
# 测试集处理进度: 12.36%
# 测试集处理进度: 12.37%
# 测试集处理进度: 12.38%
# 测试集处理进度: 12.38%
# 测试集处理进度: 12.39%
# 测试集处理进度: 12.40%
# 测试集处理进度: 12.41%
# 测试集处理进度: 12.42%
# 测试集处理进度: 12.43%
# 测试集处理进度: 12.44%
# 测试集处理进度: 12.44%
# 测试集处理进度: 12.45%
# 测试集处理进度: 12.46%
# 测试集处理进度: 12.47%
# 测试集处理进度: 12.48%
# 测试集处理进度: 12.49%
# 测试集处理进度: 12.49%
# 测试集处理进度: 12.50%
# 测试集处理进度: 12.51%
# 测试集处理进度: 12.52%
# 测试集处理进度: 12.53%
# 测试集处理进度: 12.54%
# 测试集处理进度: 12.55%
# 测试集处理进度: 12.55%
# 测试集处理进度: 12.56%
# 测试集处理进度: 12.57%
# 测试集处理进度: 12.58%
# 测试集处理进度: 12.59%
# 测试集处理进度: 12.60%
# 测试集处理进度: 12.61%
# 测试集处理进度: 12.61%
# 测试集处理进度: 12.62%
# 测试集处理进度: 12.63%
# 测试集处理进度: 12.64%
# 测试集处理进度: 12.65%
# 测试集处理进度: 12.66%
# 测试集处理进度: 12.67%
# 测试集处理进度: 12.67%
# 测试集处理进度: 12.68%
# 测试集处理进度: 12.69%
# 测试集处理进度: 12.70%
# 测试集处理进度: 12.71%
# 测试集处理进度: 12.72%
# 测试集处理进度: 12.72%
# 测试集处理进度: 12.73%
# 测试集处理进度: 12.74%
# 测试集处理进度: 12.75%
# 测试集处理进度: 12.76%
# 测试集处理进度: 12.77%
# 测试集处理进度: 12.78%
# 测试集处理进度: 12.78%
# 测试集处理进度: 12.79%
# 测试集处理进度: 12.80%
# 测试集处理进度: 12.81%
# 测试集处理进度: 12.82%
# 测试集处理进度: 12.83%
# 测试集处理进度: 12.84%
# 测试集处理进度: 12.84%
# 测试集处理进度: 12.85%
# 测试集处理进度: 12.86%
# 测试集处理进度: 12.87%
# 测试集处理进度: 12.88%
# 测试集处理进度: 12.89%
# 测试集处理进度: 12.89%
# 测试集处理进度: 12.90%
# 测试集处理进度: 12.91%
# 测试集处理进度: 12.92%
# 测试集处理进度: 12.93%
# 测试集处理进度: 12.94%
# 测试集处理进度: 12.95%
# 测试集处理进度: 12.95%
# 测试集处理进度: 12.96%
# 测试集处理进度: 12.97%
# 测试集处理进度: 12.98%
# 测试集处理进度: 12.99%
# 测试集处理进度: 13.00%
# 测试集处理进度: 13.01%
# 测试集处理进度: 13.01%
# 测试集处理进度: 13.02%
# 测试集处理进度: 16.28%
# 测试集处理进度: 16.28%
# 测试集处理进度: 16.29%
# 测试集处理进度: 16.30%
# 测试集处理进度: 16.31%
# 测试集处理进度: 16.32%
# 测试集处理进度: 16.33%
# 测试集处理进度: 16.34%
# 测试集处理进度: 16.34%
# 测试集处理进度: 16.35%
# 测试集处理进度: 16.36%
# 测试集处理进度: 16.37%
# 测试集处理进度: 16.38%
# 测试集处理进度: 16.39%
# 测试集处理进度: 16.40%
# 测试集处理进度: 16.40%
# 测试集处理进度: 16.41%
# 测试集处理进度: 16.42%
# 测试集处理进度: 16.43%
# 测试集处理进度: 16.44%
# 测试集处理进度: 16.45%
# 测试集处理进度: 16.46%
# 测试集处理进度: 16.46%
# 测试集处理进度: 16.47%
# 测试集处理进度: 16.48%
# 测试集处理进度: 16.49%
# 测试集处理进度: 16.50%
# 测试集处理进度: 16.51%
# 测试集处理进度: 16.51%
# 测试集处理进度: 16.52%
# 测试集处理进度: 16.53%
# 测试集处理进度: 16.54%
# 测试集处理进度: 16.55%
# 测试集处理进度: 16.56%
# 测试集处理进度: 16.57%
# 测试集处理进度: 16.57%
# 测试集处理进度: 16.58%
# 测试集处理进度: 16.59%
# 测试集处理进度: 16.60%
# 测试集处理进度: 16.61%
# 测试集处理进度: 16.62%
# 测试集处理进度: 16.63%
# 测试集处理进度: 16.63%
# 测试集处理进度: 16.64%
# 测试集处理进度: 16.65%
# 测试集处理进度: 16.66%
# 测试集处理进度: 16.67%
# 测试集处理进度: 16.68%
# 测试集处理进度: 16.69%
# 测试集处理进度: 16.69%
# 测试集处理进度: 16.70%
# 测试集处理进度: 16.71%
# 测试集处理进度: 16.72%
# 测试集处理进度: 16.73%
# 测试集处理进度: 16.74%
# 测试集处理进度: 16.74%
# 测试集处理进度: 16.75%
# 测试集处理进度: 16.76%
# 测试集处理进度: 16.77%
# 测试集处理进度: 16.78%
# 测试集处理进度: 16.79%
# 测试集处理进度: 16.80%
# 测试集处理进度: 16.80%
# 测试集处理进度: 16.81%
# 测试集处理进度: 16.82%
# 测试集处理进度: 16.83%
# 测试集处理进度: 16.84%
# 测试集处理进度: 16.85%
# 测试集处理进度: 16.86%
# 测试集处理进度: 16.86%
# 测试集处理进度: 16.87%
# 测试集处理进度: 16.88%
# 测试集处理进度: 16.89%
# 测试集处理进度: 16.90%
# 测试集处理进度: 16.91%
# 测试集处理进度: 16.92%
# 测试集处理进度: 16.92%
# 测试集处理进度: 16.93%
# 测试集处理进度: 16.94%
# 测试集处理进度: 16.95%
# 测试集处理进度: 16.96%
# 测试集处理进度: 16.97%
# 测试集处理进度: 16.97%
# 测试集处理进度: 16.98%
# 测试集处理进度: 16.99%
# 测试集处理进度: 17.00%
# 测试集处理进度: 17.01%
# 测试集处理进度: 17.02%
# 测试集处理进度: 17.03%
# 测试集处理进度: 17.03%
# 测试集处理进度: 17.04%
# 测试集处理进度: 17.05%
# 测试集处理进度: 17.06%
# 测试集处理进度: 17.07%
# 测试集处理进度: 17.08%
# 测试集处理进度: 17.09%
# 测试集处理进度: 17.09%
# 测试集处理进度: 17.10%
# 测试集处理进度: 17.11%
# 测试集处理进度: 17.12%
# 测试集处理进度: 17.13%
# 测试集处理进度: 17.14%
# 测试集处理进度: 17.15%
# 测试集处理进度: 17.15%
# 测试集处理进度: 17.16%
# 测试集处理进度: 17.17%
# 测试集处理进度: 17.18%
# 测试集处理进度: 17.19%
# 测试集处理进度: 17.20%
# 测试集处理进度: 17.20%
# 测试集处理进度: 17.21%
# 测试集处理进度: 17.22%
# 测试集处理进度: 17.23%
# 测试集处理进度: 17.24%
# 测试集处理进度: 17.25%
# 测试集处理进度: 17.26%
# 测试集处理进度: 17.26%
# 测试集处理进度: 17.27%
# 测试集处理进度: 17.28%
# 测试集处理进度: 17.29%
# 测试集处理进度: 17.30%
# 测试集处理进度: 17.31%
# 测试集处理进度: 17.32%
# 测试集处理进度: 17.32%
# 测试集处理进度: 17.33%
# 测试集处理进度: 17.34%
# 测试集处理进度: 17.35%
# 测试集处理进度: 17.36%
# 测试集处理进度: 17.37%
# 测试集处理进度: 17.38%
# 测试集处理进度: 17.38%
# 测试集处理进度: 17.39%
# 测试集处理进度: 17.40%
# 测试集处理进度: 17.41%
# 测试集处理进度: 17.42%
# 测试集处理进度: 17.43%
# 测试集处理进度: 17.43%
# 测试集处理进度: 17.44%
# 测试集处理进度: 17.45%
# 测试集处理进度: 17.46%
# 测试集处理进度: 17.47%
# 测试集处理进度: 17.48%
# 测试集处理进度: 17.49%
# 测试集处理进度: 17.49%
# 测试集处理进度: 17.50%
# 测试集处理进度: 17.51%
# 测试集处理进度: 17.52%
# 测试集处理进度: 17.53%
# 测试集处理进度: 17.54%
# 测试集处理进度: 17.55%
# 测试集处理进度: 17.55%
# 测试集处理进度: 17.56%
# 测试集处理进度: 17.57%
# 测试集处理进度: 17.58%
# 测试集处理进度: 17.59%
# 测试集处理进度: 17.60%
# 测试集处理进度: 17.60%
# 测试集处理进度: 17.61%
# 测试集处理进度: 17.62%
# 测试集处理进度: 17.63%
# 测试集处理进度: 17.64%
# 测试集处理进度: 17.65%
# 测试集处理进度: 17.66%
# 测试集处理进度: 17.66%
# 测试集处理进度: 17.67%
# 测试集处理进度: 17.68%
# 测试集处理进度: 17.69%
# 测试集处理进度: 17.70%
# 测试集处理进度: 17.71%
# 测试集处理进度: 17.72%
# 测试集处理进度: 17.72%
# 测试集处理进度: 17.73%
# 测试集处理进度: 17.74%
# 测试集处理进度: 17.75%
# 测试集处理进度: 17.76%
# 测试集处理进度: 17.77%
# 测试集处理进度: 17.78%
# 测试集处理进度: 17.78%
# 测试集处理进度: 17.79%
# 测试集处理进度: 17.80%
# 测试集处理进度: 17.81%
# 测试集处理进度: 17.82%
# 测试集处理进度: 17.83%
# 测试集处理进度: 17.83%
# 测试集处理进度: 17.84%
# 测试集处理进度: 17.85%
# 测试集处理进度: 17.86%
# 测试集处理进度: 17.87%
# 测试集处理进度: 17.88%
# 测试集处理进度: 17.89%
# 测试集处理进度: 19.51%
# 测试集处理进度: 19.52%
# 测试集处理进度: 19.53%
# 测试集处理进度: 19.54%
# 测试集处理进度: 19.55%
# 测试集处理进度: 19.56%
# 测试集处理进度: 19.56%
# 测试集处理进度: 19.57%
# 测试集处理进度: 19.58%
# 测试集处理进度: 19.59%
# 测试集处理进度: 19.60%
# 测试集处理进度: 19.61%
# 测试集处理进度: 19.62%
# 测试集处理进度: 19.62%
# 测试集处理进度: 19.63%
# 测试集处理进度: 19.64%
# 测试集处理进度: 19.65%
# 测试集处理进度: 19.66%
# 测试集处理进度: 19.67%
# 测试集处理进度: 19.67%
# 测试集处理进度: 19.68%
# 测试集处理进度: 19.69%
# 测试集处理进度: 19.70%
# 测试集处理进度: 19.71%
# 测试集处理进度: 19.72%
# 测试集处理进度: 19.73%
# 测试集处理进度: 19.73%
# 测试集处理进度: 19.74%
# 测试集处理进度: 19.75%
# 测试集处理进度: 19.76%
# 测试集处理进度: 19.77%
# 测试集处理进度: 19.78%
# 测试集处理进度: 19.79%
# 测试集处理进度: 19.79%
# 测试集处理进度: 19.80%
# 测试集处理进度: 19.81%
# 测试集处理进度: 19.82%
# 测试集处理进度: 19.83%
# 测试集处理进度: 19.84%
# 测试集处理进度: 19.84%
# 测试集处理进度: 19.85%
# 测试集处理进度: 19.86%
# 测试集处理进度: 19.87%
# 测试集处理进度: 19.88%
# 测试集处理进度: 19.89%
# 测试集处理进度: 19.90%
# 测试集处理进度: 19.90%
# 测试集处理进度: 19.91%
# 测试集处理进度: 19.92%
# 测试集处理进度: 19.93%
# 测试集处理进度: 19.94%
# 测试集处理进度: 19.95%
# 测试集处理进度: 19.96%
# 测试集处理进度: 19.96%
# 测试集处理进度: 19.97%
# 测试集处理进度: 19.98%
# 测试集处理进度: 19.99%
# 测试集处理进度: 20.00%
# 测试集处理进度: 20.01%
# 测试集处理进度: 20.02%
# 测试集处理进度: 20.02%
# 测试集处理进度: 20.03%
# 测试集处理进度: 20.04%
# 测试集处理进度: 20.05%
# 测试集处理进度: 20.06%
# 测试集处理进度: 20.07%
# 测试集处理进度: 20.07%
# 测试集处理进度: 20.08%
# 测试集处理进度: 20.09%
# 测试集处理进度: 20.10%
# 测试集处理进度: 20.11%
# 测试集处理进度: 20.12%
# 测试集处理进度: 20.13%
# 测试集处理进度: 20.13%
# 测试集处理进度: 20.14%
# 测试集处理进度: 20.15%
# 测试集处理进度: 20.16%
# 测试集处理进度: 20.17%
# 测试集处理进度: 20.18%
# 测试集处理进度: 20.19%
# 测试集处理进度: 20.19%
# 测试集处理进度: 20.20%
# 测试集处理进度: 20.21%
# 测试集处理进度: 20.22%
# 测试集处理进度: 20.23%
# 测试集处理进度: 20.24%
# 测试集处理进度: 20.25%
# 测试集处理进度: 20.25%
# 测试集处理进度: 20.26%
# 测试集处理进度: 20.27%
# 测试集处理进度: 20.28%
# 测试集处理进度: 20.29%
# 测试集处理进度: 20.30%
# 测试集处理进度: 20.30%
# 测试集处理进度: 20.31%
# 测试集处理进度: 20.32%
# 测试集处理进度: 20.33%
# 测试集处理进度: 20.34%
# 测试集处理进度: 20.35%
# 测试集处理进度: 20.36%
# 测试集处理进度: 20.36%
# 测试集处理进度: 20.37%
# 测试集处理进度: 20.38%
# 测试集处理进度: 20.39%
# 测试集处理进度: 20.40%
# 测试集处理进度: 20.41%
# 测试集处理进度: 20.42%
# 测试集处理进度: 20.42%
# 测试集处理进度: 20.43%
# 测试集处理进度: 20.44%
# 测试集处理进度: 20.45%
# 测试集处理进度: 20.46%
# 测试集处理进度: 20.47%
# 测试集处理进度: 20.48%
# 测试集处理进度: 20.48%
# 测试集处理进度: 20.49%
# 测试集处理进度: 20.50%
# 测试集处理进度: 20.51%
# 测试集处理进度: 20.52%
# 测试集处理进度: 20.53%
# 测试集处理进度: 20.53%
# 测试集处理进度: 20.54%
# 测试集处理进度: 20.55%
# 测试集处理进度: 20.56%
# 测试集处理进度: 20.57%
# 测试集处理进度: 20.58%
# 测试集处理进度: 20.59%
# 测试集处理进度: 20.59%
# 测试集处理进度: 20.60%
# 测试集处理进度: 20.61%
# 测试集处理进度: 20.62%
# 测试集处理进度: 20.63%
# 测试集处理进度: 20.64%
# 测试集处理进度: 20.65%
# 测试集处理进度: 20.65%
# 测试集处理进度: 20.66%
# 测试集处理进度: 20.67%
# 测试集处理进度: 20.68%
# 测试集处理进度: 20.69%
# 测试集处理进度: 20.70%
# 测试集处理进度: 20.71%
# 测试集处理进度: 20.71%
# 测试集处理进度: 20.72%
# 测试集处理进度: 20.73%
# 测试集处理进度: 20.74%
# 测试集处理进度: 20.75%
# 测试集处理进度: 20.76%
# 测试集处理进度: 20.76%
# 测试集处理进度: 20.77%
# 测试集处理进度: 20.78%
# 测试集处理进度: 20.79%
# 测试集处理进度: 20.80%
# 测试集处理进度: 20.81%
# 测试集处理进度: 20.82%
# 测试集处理进度: 20.82%
# 测试集处理进度: 20.83%
# 测试集处理进度: 20.84%
# 测试集处理进度: 20.85%
# 测试集处理进度: 20.86%
# 测试集处理进度: 20.87%
# 测试集处理进度: 20.88%
# 测试集处理进度: 20.88%
# 测试集处理进度: 20.89%
# 测试集处理进度: 20.90%
# 测试集处理进度: 20.91%
# 测试集处理进度: 20.92%
# 测试集处理进度: 20.93%
# 测试集处理进度: 20.94%
# 测试集处理进度: 20.94%
# 测试集处理进度: 20.95%
# 测试集处理进度: 20.96%
# 测试集处理进度: 20.97%
# 测试集处理进度: 20.98%
# 测试集处理进度: 20.99%
# 测试集处理进度: 20.99%
# 测试集处理进度: 21.00%
# 测试集处理进度: 21.01%
# 测试集处理进度: 21.02%
# 测试集处理进度: 21.03%
# 测试集处理进度: 21.04%
# 测试集处理进度: 21.05%
# 测试集处理进度: 21.05%
# 测试集处理进度: 21.06%
# 测试集处理进度: 21.07%
# 测试集处理进度: 21.08%
# 测试集处理进度: 21.09%
# 测试集处理进度: 21.10%
# 测试集处理进度: 21.11%
# 测试集处理进度: 21.11%
# 测试集处理进度: 21.12%
# 测试集处理进度: 21.13%
# 测试集处理进度: 21.14%
# 测试集处理进度: 21.15%
# 测试集处理进度: 21.16%
# 测试集处理进度: 21.17%
# 测试集处理进度: 21.17%
# 测试集处理进度: 21.18%
# 测试集处理进度: 21.19%
# 测试集处理进度: 21.20%
# 测试集处理进度: 21.21%
# 测试集处理进度: 21.22%
# 测试集处理进度: 21.22%
# 测试集处理进度: 21.23%
# 测试集处理进度: 21.24%
# 测试集处理进度: 21.25%
# 测试集处理进度: 21.26%
# 测试集处理进度: 21.27%
# 测试集处理进度: 21.28%
# 测试集处理进度: 21.28%
# 测试集处理进度: 21.29%
# 测试集处理进度: 21.30%
# 测试集处理进度: 21.31%
# 测试集处理进度: 21.32%
# 测试集处理进度: 21.33%
# 测试集处理进度: 21.34%
# 测试集处理进度: 21.34%
# 测试集处理进度: 21.35%
# 测试集处理进度: 21.36%
# 测试集处理进度: 21.37%
# 测试集处理进度: 21.38%
# 测试集处理进度: 21.39%
# 测试集处理进度: 21.40%
# 测试集处理进度: 21.40%
# 测试集处理进度: 21.41%
# 测试集处理进度: 21.42%
# 测试集处理进度: 21.43%
# 测试集处理进度: 21.44%
# 测试集处理进度: 21.45%
# 测试集处理进度: 21.45%
# 测试集处理进度: 21.46%
# 测试集处理进度: 21.47%
# 测试集处理进度: 21.48%
# 测试集处理进度: 21.49%
# 测试集处理进度: 21.50%
# 测试集处理进度: 21.51%
# 测试集处理进度: 21.51%
# 测试集处理进度: 21.52%
# 测试集处理进度: 21.53%
# 测试集处理进度: 21.54%
# 测试集处理进度: 21.55%
# 测试集处理进度: 21.56%
# 测试集处理进度: 21.57%
# 测试集处理进度: 21.57%
# 测试集处理进度: 21.58%
# 测试集处理进度: 21.59%
# 测试集处理进度: 21.60%
# 测试集处理进度: 21.61%
# 测试集处理进度: 21.62%
# 测试集处理进度: 21.63%
# 测试集处理进度: 21.63%
# 测试集处理进度: 21.64%
# 测试集处理进度: 21.65%
# 测试集处理进度: 21.66%
# 测试集处理进度: 21.67%
# 测试集处理进度: 21.68%
# 测试集处理进度: 21.68%
# 测试集处理进度: 21.69%
# 测试集处理进度: 21.70%
# 测试集处理进度: 21.71%
# 测试集处理进度: 21.72%
# 测试集处理进度: 21.73%
# 测试集处理进度: 21.74%
# 测试集处理进度: 21.74%
# 测试集处理进度: 21.75%
# 测试集处理进度: 21.76%
# 测试集处理进度: 21.77%
# 测试集处理进度: 21.78%
# 测试集处理进度: 21.79%
# 测试集处理进度: 21.80%
# 测试集处理进度: 21.80%
# 测试集处理进度: 21.81%
# 测试集处理进度: 21.82%
# 测试集处理进度: 21.83%
# 测试集处理进度: 21.84%
# 测试集处理进度: 21.85%
# 测试集处理进度: 21.86%
# 测试集处理进度: 21.86%
# 测试集处理进度: 21.87%
# 测试集处理进度: 21.88%
# 测试集处理进度: 21.89%
# 测试集处理进度: 21.90%
# 测试集处理进度: 21.91%
# 测试集处理进度: 21.91%
# 测试集处理进度: 21.92%
# 测试集处理进度: 21.93%
# 测试集处理进度: 21.94%
# 训练集处理进度: 96.57%
# 训练集处理进度: 96.57%
# 训练集处理进度: 96.57%
# 训练集处理进度: 96.58%
# 训练集处理进度: 96.58%
# 训练集处理进度: 96.59%
# 训练集处理进度: 96.59%
# 训练集处理进度: 96.59%
# 训练集处理进度: 96.60%
# 训练集处理进度: 96.60%
# 训练集处理进度: 96.60%
# 训练集处理进度: 96.61%
# 训练集处理进度: 96.61%
# 训练集处理进度: 96.61%
# 训练集处理进度: 96.62%
# 训练集处理进度: 96.62%
# 训练集处理进度: 96.63%
# 训练集处理进度: 96.63%
# 训练集处理进度: 96.63%
# 训练集处理进度: 96.64%
# 训练集处理进度: 96.64%
# 训练集处理进度: 96.64%
# 训练集处理进度: 96.65%
# 训练集处理进度: 96.65%
# 训练集处理进度: 96.65%
# 训练集处理进度: 96.66%
# 训练集处理进度: 96.66%
# 训练集处理进度: 96.67%
# 训练集处理进度: 96.67%
# 训练集处理进度: 96.67%
# 训练集处理进度: 96.68%
# 训练集处理进度: 96.68%
# 训练集处理进度: 96.68%
# 训练集处理进度: 96.69%
# 训练集处理进度: 96.69%
# 训练集处理进度: 96.69%
# 训练集处理进度: 96.70%
# 训练集处理进度: 96.70%
# 训练集处理进度: 96.71%
# 训练集处理进度: 96.71%
# 训练集处理进度: 96.71%
# 训练集处理进度: 96.72%
# 训练集处理进度: 96.72%
# 训练集处理进度: 96.72%
# 训练集处理进度: 96.73%
# 训练集处理进度: 96.73%
# 训练集处理进度: 96.73%
# 训练集处理进度: 96.74%
# 训练集处理进度: 96.74%
# 训练集处理进度: 96.75%
# 训练集处理进度: 96.75%
# 训练集处理进度: 96.75%
# 训练集处理进度: 96.76%
# 训练集处理进度: 96.76%
# 训练集处理进度: 96.76%
# 训练集处理进度: 96.77%
# 训练集处理进度: 96.77%
# 训练集处理进度: 96.78%
# 训练集处理进度: 96.78%
# 训练集处理进度: 96.78%
# 训练集处理进度: 96.79%
# 训练集处理进度: 96.79%
# 训练集处理进度: 96.79%
# 训练集处理进度: 96.80%
# 训练集处理进度: 96.80%
# 训练集处理进度: 96.80%
# 训练集处理进度: 96.81%
# 训练集处理进度: 96.81%
# 训练集处理进度: 96.82%
# 训练集处理进度: 96.82%
# 训练集处理进度: 96.82%
# 训练集处理进度: 96.83%
# 训练集处理进度: 96.83%
# 训练集处理进度: 96.83%
# 训练集处理进度: 96.84%
# 训练集处理进度: 96.84%
# 训练集处理进度: 96.84%
# 训练集处理进度: 96.85%
# 训练集处理进度: 96.85%
# 训练集处理进度: 96.86%
# 训练集处理进度: 96.86%
# 训练集处理进度: 96.86%
# 训练集处理进度: 96.87%
# 训练集处理进度: 96.87%
# 训练集处理进度: 96.87%
# 训练集处理进度: 96.88%
# 训练集处理进度: 96.88%
# 训练集处理进度: 96.88%
# 训练集处理进度: 96.89%
# 训练集处理进度: 96.89%
# 训练集处理进度: 96.90%
# 训练集处理进度: 96.90%
# 训练集处理进度: 96.90%
# 训练集处理进度: 96.91%
# 训练集处理进度: 96.91%
# 训练集处理进度: 99.00%
# 训练集处理进度: 99.00%
# 训练集处理进度: 99.01%
# 训练集处理进度: 99.01%
# 训练集处理进度: 99.01%
#
# 处理结果统计:
# 有效测试样本数: 11625/11741
# 有效训练样本数: 27110/27380

# %%
print(type(train_data_list))
print(len(test_data_list))
print(test_data_list[0].shape)
# Out:
# <class 'list'>
# 11625
# torch.Size([64, 640])

# %%
class dataset(torch.utils.data.Dataset):
    def __init__(self, datas, labels):
        self.datas = datas
        self.labels = labels

    def __getitem__(self, index):
        eeg = self.datas[index]
        label = self.labels[index]

        return eeg, torch.tensor(label, dtype=torch.long)
    
    def __len__(self):
        return len(self.datas)
        
train_set = dataset(train_data_list, train_label_list)
test_set = dataset(test_data_list, test_label_list)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False, drop_last=True)

# %%
simple_batch = train_set[1][0]
simple_batch = simple_batch[None, :]

class SELayer1D(nn.Module):
    def __init__(self, channels, reduction_ratio=8):
        super().__init__()
        assert channels % reduction_ratio == 0, f"通道数{channels}必须能被reduction_ratio{reduction_ratio}整除"
        
        self.avg_pool = nn.AdaptiveAvgPool1d(1)  # 针对一维特征的全局池化
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction_ratio, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction_ratio, channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, l = x.size()
        
        # Squeeze
        y = self.avg_pool(x)
        y = y.view(b, c)
        
        # Excitation
        y = self.fc(y)
        y = y.view(b, c, 1)
        
        # Scale
        return x * y.expand_as(x)

class CMO_CNN(nn.Module):
    def __init__(self):
        super(CMO_CNN, self).__init__()

        #branch1
        self.c1 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=20, stride=2, padding=0)
        self.bn1 = nn.BatchNorm1d(num_features=32)
        self.e1 = nn.ELU()
        self.se1 = SELayer1D(32)
        self.mp1 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c2 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=9, stride=2, padding=0)
        self.bn2 = nn.BatchNorm1d(num_features=32)
        self.e2 = nn.ELU()
        self.se2 = SELayer1D(32)
        self.mp2 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c3 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(num_features=32)
        self.e3 = nn.ELU()
        self.c4 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(num_features=32)
        self.e4 = nn.ELU()
        self.se3 = SELayer1D(32)
        self.mp3 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c5 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn5 = nn.BatchNorm1d(num_features=32)
        self.e5 = nn.ELU()
        self.c6 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn6 = nn.BatchNorm1d(num_features=32)
        self.e6 = nn.ELU()
        self.se4 = SELayer1D(32)
        self.mp4 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.d1 = nn.Dropout(p=0.5)
        self.f1 = nn.Flatten()

        #branch2
        self.c7 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=13, stride=2, padding=0)
        self.bn7 = nn.BatchNorm1d(num_features=32)
        self.e7 = nn.ELU()
        self.se5 = SELayer1D(32)
        self.c8 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=7, stride=2, padding=0)
        self.bn8 = nn.BatchNorm1d(num_features=32)
        self.e8 = nn.ELU()
        self.se6 = SELayer1D(32)
        self.mp5 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c9 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=5, stride=1, padding=0)
        self.bn9 = nn.BatchNorm1d(num_features=32)
        self.e9 = nn.ELU()
        self.se7 = SELayer1D(32)
        self.mp6 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c10 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn10 = nn.BatchNorm1d(num_features=32)
        self.e10 = nn.ELU()
        self.c11 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn11 = nn.BatchNorm1d(num_features=32)
        self.e11 = nn.ELU()
        self.se8 = SELayer1D(32)
        self.mp7 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.d2 = nn.Dropout(p=0.5)
        self.f2 = nn.Flatten()

        #branch3
        self.c12 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=15, stride=2, padding=0)
        self.bn12 = nn.BatchNorm1d(num_features=32)
        self.e12 = nn.ELU()
        self.se9 = SELayer1D(32)
        self.mp8 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c13 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=10, stride=2, padding=0)
        self.bn13 = nn.BatchNorm1d(num_features=32)
        self.e13 = nn.ELU()
        self.se10 = SELayer1D(32)
        self.c14 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=5, stride=1, padding=0)
        self.bn14 = nn.BatchNorm1d(num_features=32)
        self.e14 = nn.ELU()
        self.se11 = SELayer1D(32)
        self.mp9 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.c15 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=0)
        self.bn15 = nn.BatchNorm1d(num_features=32)
        self.e15 = nn.ELU()
        self.se12 = SELayer1D(32)
        self.mp10 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.d3 = nn.Dropout(p=0.5)
        self.f3 = nn.Flatten()


    def forward(self, x):
        #branch1
        x1 = x.clone()
        x1 = self.c1(x1)
        x1 = self.bn1(x1)
        x1 = self.e1(x1)
        x1 = self.se1(x1)
        x1 = self.mp1(x1)
        x1 = self.c2(x1)
        x1 = self.bn2(x1)
        x1 = self.e2(x1)
        x1 = self.se2(x1)
        x1 = self.mp2(x1)
        x1_r = x1.clone()
        x1 = self.c3(x1)
        x1 = self.bn3(x1)
        x1 = self.e3(x1)
        x1 = self.c4(x1)
        x1 = self.bn4(x1)
        x1 = self.e4(x1)
        x1 = self.se3(x1)
        x1 += x1_r
        x1 = self.mp3(x1)
        x1_r = x1.clone()
        x1 = self.c5(x1)
        x1 = self.bn5(x1)
        x1 = self.e5(x1)
        x1 = self.c6(x1)
        x1 = self.bn6(x1)
        x1 = self.e6(x1)
        x1 = self.se4(x1)
        x1 += x1_r
        x1 = self.mp4(x1)
        x1 = self.d1(x1)
        x1 = self.f1(x1)

        #branch2
        x2 = x.clone()
        x2 = self.c7(x2)
        x2 = self.bn7(x2)
        x2 = self.e7(x2)
        x2 = self.se5(x2)
        x2 = self.c8(x2)
        x2 = self.bn8(x2)
        x2 = self.e8(x2)
        x2 = self.se6(x2)
        x2 = self.mp5(x2)
        x2 = self.c9(x2)
        x2 = self.bn9(x2)
        x2 = self.e9(x2)
        x2 = self.se7(x2)
        x2 = self.mp6(x2)
        x2_r = x2.clone()
        x2 = self.c10(x2)
        x2 = self.bn10(x2)
        x2 = self.e10(x2)
        x2 = self.c11(x2)
        x2 = self.bn11(x2)
        x2 = self.e11(x2)
        x2 = self.se8(x2)
        x2 += x2_r
        x2 = self.mp7(x2)
        x2 = self.d1(x2)
        x2 = self.f1(x2)

        #branch3
        x3 = x.clone()
        x3 = self.c12(x3)
        x3 = self.bn12(x3)
        x3 = self.e12(x3)
        x3 = self.se9(x3)
        x3 = self.mp8(x3)
        x3 = self.c13(x3)
        x3 = self.bn13(x3)
        x3 = self.e13(x3)
        x3 = self.se10(x3)
        x3 = self.c14(x3)
        x3 = self.bn14(x3)
        x3 = self.e14(x3)
        x3 = self.se11(x3)
        x3 = self.mp9(x3)
        x3 = self.bn15(x3)
        x3 = self.e15(x3)
        x3 = self.se12(x3)
        x3 = self.mp10(x3)
        x3 = self.d1(x3)
        x3 = self.f1(x3)

        feature = torch.cat((x1, x2, x3), axis=1)

        return feature

class ClassificationHead(nn.Module):
    def __init__(self, 
                 input_dim=512, 
                 num_classes=8,
                 hidden_dims=[512, 256, 128],      # 隐藏层维度设置
                 dropout_prob=0.3,       # Dropout概率
                 use_batchnorm=False):   # 是否使用批归一化
        super().__init__()
        
        layers = []
        current_dim = input_dim
        
        # 动态构建隐藏层
        for h_dim in hidden_dims:
            layers.append(nn.Linear(current_dim, h_dim))
            
            if use_batchnorm:
                layers.append(nn.BatchNorm1d(h_dim))
                
            layers.append(nn.ReLU(inplace=True))
            
            if dropout_prob > 0:
                layers.append(nn.Dropout(p=dropout_prob))
            
            current_dim = h_dim
        
        # 最终分类层
        layers.append(nn.Linear(current_dim, num_classes))
        
        self.head = nn.Sequential(*layers)
        
        # 权重初始化
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
    
    def forward(self, x):
        return self.head(x)
#初始化模型
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = CMO_CNN()
        self.classifier = ClassificationHead(input_dim=1408, num_classes=9)

    def forward(self, x):
        features = self.backbone(x)
        logits = self.classifier(features)
        return logits
model = Model().to(device)

#-----------------------------------------------------------------------------------------------------------------------------------------------------
#loss函数类加权
class_counts = np.array([13705, 1711, 1724, 1696, 1715, 1709, 1694, 1716, 1710])
median = np.median(class_counts)
weights = median / class_counts
weights = torch.tensor(weights, dtype=torch.float32)
weights = torch.softmax(weights, axis=0)
print("各类别权重:")
for i, w in enumerate(weights.numpy()):
    print(f"cls{i}: {w:.4f}")

# 数据加载器应使用加权采样
from torch.utils.data import WeightedRandomSampler

sample_weights = [weights[target] for (data, target) in train_set]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))
train_loader = DataLoader(train_set, batch_size=64, sampler=sampler)

def focal_loss(input_values, gamma):
    """Computes the focal loss"""
    p = torch.exp(-input_values)   #目标类概率
    loss = (1 - p.detach()) ** gamma * input_values
    return loss.mean()


class FocalLoss(nn.Module):
    def __init__(self, weight=None, gamma=0.):
        super(FocalLoss, self).__init__()
        assert gamma >= 0
        self.gamma = gamma
        self.weight = weight

    def forward(self, input, target):
        return focal_loss(F.cross_entropy(input, target, reduction='none', weight=self.weight), self.gamma)

"""class DynamicFocalLoss(nn.Module):
    def __init__(self, class_counts, gamma=2.0, temp=0.5, smooth=1e-6):
        super().__init__()
        self.gamma = gamma
        self.temp = temp
        self.smooth = smooth
        
        # 初始化基权重（基于全局分布）
        self.base_weights = self._compute_base_weights(class_counts)
        
    def _compute_base_weights(self, class_counts):
        counts = torch.tensor(class_counts) if not isinstance(class_counts, torch.Tensor) else class_counts
        return 1.0 / torch.sqrt(counts.float() + self.smooth)
    
    def forward(self, inputs, targets):
        # 动态计算当前batch的类别分布
        batch_counts = torch.bincount(targets, minlength=len(self.base_weights))
        batch_weights = 1.0 / (batch_counts.float() + self.smooth)
        
        # 混合基权重与动态权重
        dynamic_weights = self.temp * self.base_weights.to(inputs.device) + (1 - self.temp) * batch_weights.to(inputs.device)
        
        # 权重归一化（保持均值1）
        dynamic_weights = dynamic_weights / dynamic_weights.mean()
        
        # 计算带权重的交叉熵损失
        ce_loss = F.cross_entropy(
            inputs, targets,
            weight=dynamic_weights,
            reduction='none'  # 保持每个样本的损失值
        )
        
        # 计算Focal Loss
        p = torch.exp(-ce_loss.detach())  # 目标类概率
        focal_loss = (1 - p) ** self.gamma * ce_loss
        
        return focal_loss.mean()"""

#类加权
#loss函数类加权
class_counts = np.array([13705, 1711, 1724, 1696, 1715, 1709, 1694, 1716, 1710])
median = np.median(class_counts)
weights = median / class_counts
weights = torch.tensor(weights, dtype=torch.float32)
weights = torch.softmax(weights, axis=0)

# 交叉熵损失
ce_loss = nn.CrossEntropyLoss()

#=====================================================================================================================================================
# 阶段1：正常训练全部参数
#=====================================================================================================================================================
criterion_t1= torch.nn.CrossEntropyLoss()
optimizer_t1 = optim.Adam(list(model.parameters()), lr=LEARNING_RATE)
#=====================================================================================================================================================
# 阶段2：冻结backbone，平衡采样
#=====================================================================================================================================================
#微噪声
criterion_t2 = FocalLoss(weight=weights.to(device), gamma=1).to(device)
optimizer_t2 = optim.Adam(list(model.classifier.parameters()), lr=LEARNING_RATE)
# Out:
# 各类别权重:
# cls0: 0.0495
# cls1: 0.1187
# cls2: 0.1178
# cls3: 0.1198
# cls4: 0.1184
# cls5: 0.1188
# cls6: 0.1199
# cls7: 0.1184
# cls8: 0.1188

# %%
print("==== 第一阶段训练（原始数据）====")
for epoch in range(40):
    model.train()
    total_loss = 0
    total_ce = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer_t1.zero_grad()  # 清空梯度
        outputs = model(X_batch)
        loss = criterion_t1(outputs, y_batch)  # 计算损失
        loss.backward()  # 反向传播
        optimizer_t1.step()  # 更新参数

        total_loss += loss.item()

        #观测CE值
        loss_ce = ce_loss(outputs, y_batch)
        total_ce += loss_ce.item()

    print(f"Epoch [{epoch+1}] CELoss: {total_loss / len(train_loader):.6f} CELoss: {total_ce / len(train_loader):.6f}")

print("\n==== 第二阶段训练（平衡数据）====")
for param in model.backbone.parameters():
    param.requires_grad = False
#加权采样
sample_weights = [weights[target] for (data, target) in train_set]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))
train_loader = DataLoader(train_set, batch_size=48, sampler=sampler)
for epoch in range(200):
    model.train()
    total_loss = 0
    total_ce = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer_t2.zero_grad()  # 清空梯度
        outputs = model(X_batch)
        loss = criterion_t2(outputs, y_batch)  # 计算损失
        loss.backward()  # 反向传播
        optimizer_t2.step()  # 更新参数

        total_loss += loss.item()

        #观测CE值
        loss_ce = ce_loss(outputs, y_batch)
        total_ce += loss_ce.item()

    print(f"Epoch [{epoch+1}] FLLoss: {total_loss / len(train_loader):.6f} CELoss: {total_ce / len(train_loader):.6f}")
# Out:
# ==== 第一阶段训练（原始数据）====
# Epoch [1] CELoss: 0.544688 CELoss: 0.544688
# Epoch [2] CELoss: 0.519429 CELoss: 0.519429
# Epoch [3] CELoss: 0.514725 CELoss: 0.514725
# Epoch [4] CELoss: 0.513080 CELoss: 0.513080
# Epoch [5] CELoss: 0.502091 CELoss: 0.502091
# Epoch [6] CELoss: 0.515638 CELoss: 0.515638
# Epoch [7] CELoss: 0.507640 CELoss: 0.507640
# Epoch [8] CELoss: 0.511330 CELoss: 0.511330
# Epoch [9] CELoss: 0.505509 CELoss: 0.505509
# Epoch [10] CELoss: 0.499053 CELoss: 0.499053
# Epoch [11] CELoss: 0.492869 CELoss: 0.492869
# Epoch [12] CELoss: 0.480356 CELoss: 0.480356
# Epoch [13] CELoss: 0.491007 CELoss: 0.491007
# Epoch [14] CELoss: 0.482958 CELoss: 0.482958
# Epoch [15] CELoss: 0.479543 CELoss: 0.479543
# Epoch [16] CELoss: 0.479538 CELoss: 0.479538
# Epoch [17] CELoss: 0.485833 CELoss: 0.485833
# Epoch [18] CELoss: 0.479879 CELoss: 0.479879
# Epoch [19] CELoss: 0.455053 CELoss: 0.455053
# Epoch [20] CELoss: 0.466253 CELoss: 0.466253
# Epoch [21] CELoss: 0.462462 CELoss: 0.462462
# Epoch [22] CELoss: 0.459586 CELoss: 0.459586
# Epoch [23] CELoss: 0.468632 CELoss: 0.468632
# Epoch [24] CELoss: 0.457384 CELoss: 0.457384
# Epoch [25] CELoss: 0.465571 CELoss: 0.465571
# Epoch [26] CELoss: 0.460791 CELoss: 0.460791
# Epoch [27] CELoss: 0.456126 CELoss: 0.456126
# Epoch [28] CELoss: 0.454207 CELoss: 0.454207
# Epoch [29] CELoss: 0.447836 CELoss: 0.447836
# Epoch [30] CELoss: 0.463459 CELoss: 0.463459
# Epoch [31] CELoss: 0.439264 CELoss: 0.439264
# Epoch [32] CELoss: 0.454137 CELoss: 0.454137
# Epoch [33] CELoss: 0.444983 CELoss: 0.444983
# Epoch [34] CELoss: 0.455858 CELoss: 0.455858
# Epoch [35] CELoss: 0.457794 CELoss: 0.457794
# Epoch [36] CELoss: 0.439930 CELoss: 0.439930
# Epoch [37] CELoss: 0.448475 CELoss: 0.448475
# Epoch [38] CELoss: 0.443378 CELoss: 0.443378
# Epoch [39] CELoss: 0.448802 CELoss: 0.448802
# Epoch [40] CELoss: 0.423106 CELoss: 0.423106
#
# ==== 第二阶段训练（平衡数据）====
# Epoch [1] FLLoss: 0.006954 CELoss: 0.495209
# Epoch [2] FLLoss: 0.006267 CELoss: 0.543794
# Epoch [3] FLLoss: 0.006331 CELoss: 0.561669
# Epoch [4] FLLoss: 0.006193 CELoss: 0.557417
# Epoch [5] FLLoss: 0.005947 CELoss: 0.555150
# Epoch [6] FLLoss: 0.006009 CELoss: 0.556295
# Epoch [7] FLLoss: 0.005890 CELoss: 0.545836
# Epoch [8] FLLoss: 0.006167 CELoss: 0.560046
# Epoch [9] FLLoss: 0.005973 CELoss: 0.548691
# Epoch [10] FLLoss: 0.006077 CELoss: 0.562031
# Epoch [11] FLLoss: 0.006085 CELoss: 0.564621
# Epoch [12] FLLoss: 0.006097 CELoss: 0.556829
# Epoch [13] FLLoss: 0.006149 CELoss: 0.558930
# Epoch [14] FLLoss: 0.005839 CELoss: 0.555075
# Epoch [15] FLLoss: 0.005915 CELoss: 0.551054
# Epoch [16] FLLoss: 0.005858 CELoss: 0.551025
# Epoch [17] FLLoss: 0.005690 CELoss: 0.541401
# Epoch [18] FLLoss: 0.005952 CELoss: 0.555870
# Epoch [19] FLLoss: 0.005802 CELoss: 0.544408
# Epoch [20] FLLoss: 0.005790 CELoss: 0.547267
# Epoch [21] FLLoss: 0.005990 CELoss: 0.552436
# Epoch [22] FLLoss: 0.005785 CELoss: 0.545330
# Epoch [23] FLLoss: 0.005728 CELoss: 0.540540
# Epoch [24] FLLoss: 0.005793 CELoss: 0.547236
# Epoch [25] FLLoss: 0.005634 CELoss: 0.537935
# Epoch [26] FLLoss: 0.005847 CELoss: 0.548228
# Epoch [27] FLLoss: 0.005825 CELoss: 0.540861
# Epoch [28] FLLoss: 0.005792 CELoss: 0.546976
# Epoch [29] FLLoss: 0.005817 CELoss: 0.550027
# Epoch [30] FLLoss: 0.005622 CELoss: 0.539812
# Epoch [31] FLLoss: 0.005798 CELoss: 0.544026
# Epoch [32] FLLoss: 0.005629 CELoss: 0.541292
# Epoch [33] FLLoss: 0.005722 CELoss: 0.551458
# Epoch [34] FLLoss: 0.005778 CELoss: 0.545044
# Epoch [35] FLLoss: 0.005693 CELoss: 0.543011
# Epoch [36] FLLoss: 0.005481 CELoss: 0.531238
# Epoch [37] FLLoss: 0.005485 CELoss: 0.538625
# Epoch [38] FLLoss: 0.005597 CELoss: 0.535041
# Epoch [39] FLLoss: 0.005647 CELoss: 0.540596
# Epoch [40] FLLoss: 0.005504 CELoss: 0.536397
# Epoch [41] FLLoss: 0.005815 CELoss: 0.547381
# Epoch [42] FLLoss: 0.005525 CELoss: 0.539085
# Epoch [43] FLLoss: 0.005483 CELoss: 0.530588
# Epoch [44] FLLoss: 0.005729 CELoss: 0.537012
# Epoch [45] FLLoss: 0.005486 CELoss: 0.531208
# Epoch [46] FLLoss: 0.005459 CELoss: 0.537067
# Epoch [47] FLLoss: 0.005402 CELoss: 0.522747
# Epoch [48] FLLoss: 0.005467 CELoss: 0.533580
# Epoch [49] FLLoss: 0.005456 CELoss: 0.534458
# Epoch [50] FLLoss: 0.005431 CELoss: 0.535833
# Epoch [51] FLLoss: 0.005396 CELoss: 0.526898
# Epoch [52] FLLoss: 0.005432 CELoss: 0.528269
# Epoch [53] FLLoss: 0.005593 CELoss: 0.530475
# Epoch [54] FLLoss: 0.005696 CELoss: 0.538473
# Epoch [55] FLLoss: 0.005253 CELoss: 0.527013
# Epoch [56] FLLoss: 0.005364 CELoss: 0.524628
# Epoch [57] FLLoss: 0.005277 CELoss: 0.522519
# Epoch [58] FLLoss: 0.005633 CELoss: 0.538775
# Epoch [59] FLLoss: 0.005278 CELoss: 0.525933
# Epoch [60] FLLoss: 0.005331 CELoss: 0.522759
# Epoch [61] FLLoss: 0.005348 CELoss: 0.529408
# Epoch [62] FLLoss: 0.005463 CELoss: 0.526794
# Epoch [63] FLLoss: 0.005446 CELoss: 0.533456
# Epoch [64] FLLoss: 0.005374 CELoss: 0.524883
# Epoch [65] FLLoss: 0.005225 CELoss: 0.521824
# Epoch [66] FLLoss: 0.005298 CELoss: 0.523083
# Epoch [67] FLLoss: 0.005417 CELoss: 0.527123
# Epoch [68] FLLoss: 0.005369 CELoss: 0.526326
# Epoch [69] FLLoss: 0.005419 CELoss: 0.526661
# Epoch [70] FLLoss: 0.005351 CELoss: 0.516846
# Epoch [71] FLLoss: 0.005393 CELoss: 0.521639
# Epoch [72] FLLoss: 0.005459 CELoss: 0.529517
# Epoch [73] FLLoss: 0.005350 CELoss: 0.526986
# Epoch [74] FLLoss: 0.005316 CELoss: 0.522243
# Epoch [75] FLLoss: 0.005380 CELoss: 0.527577
# Epoch [76] FLLoss: 0.005224 CELoss: 0.513750
# Epoch [77] FLLoss: 0.005310 CELoss: 0.523785
# Epoch [78] FLLoss: 0.005405 CELoss: 0.526113
# Epoch [79] FLLoss: 0.005031 CELoss: 0.514588
# Epoch [80] FLLoss: 0.005240 CELoss: 0.518948
# Epoch [81] FLLoss: 0.005311 CELoss: 0.522424
# Epoch [82] FLLoss: 0.005335 CELoss: 0.520631
# Epoch [83] FLLoss: 0.005118 CELoss: 0.516853
# Epoch [84] FLLoss: 0.005282 CELoss: 0.516765
# Epoch [85] FLLoss: 0.005453 CELoss: 0.528187
# Epoch [86] FLLoss: 0.005295 CELoss: 0.523851
# Epoch [87] FLLoss: 0.005168 CELoss: 0.517986
# Epoch [88] FLLoss: 0.005163 CELoss: 0.519231
# Epoch [89] FLLoss: 0.005205 CELoss: 0.515459
# Epoch [90] FLLoss: 0.005233 CELoss: 0.516543
# Epoch [91] FLLoss: 0.005174 CELoss: 0.516113
# Epoch [92] FLLoss: 0.005138 CELoss: 0.509639
# Epoch [93] FLLoss: 0.005161 CELoss: 0.512253
# Epoch [94] FLLoss: 0.005067 CELoss: 0.507575
# Epoch [95] FLLoss: 0.005227 CELoss: 0.519657
# Epoch [96] FLLoss: 0.005121 CELoss: 0.511857
# Epoch [97] FLLoss: 0.004988 CELoss: 0.506612
# Epoch [98] FLLoss: 0.005149 CELoss: 0.511445
# Epoch [99] FLLoss: 0.005045 CELoss: 0.509591
# Epoch [100] FLLoss: 0.005019 CELoss: 0.504969
# Epoch [101] FLLoss: 0.005173 CELoss: 0.511646
# Epoch [102] FLLoss: 0.004921 CELoss: 0.498524
# Epoch [103] FLLoss: 0.004996 CELoss: 0.501266
# Epoch [104] FLLoss: 0.004956 CELoss: 0.501258
# Epoch [105] FLLoss: 0.005067 CELoss: 0.506204
# Epoch [106] FLLoss: 0.005028 CELoss: 0.505113
# Epoch [107] FLLoss: 0.005123 CELoss: 0.506540
# Epoch [108] FLLoss: 0.005149 CELoss: 0.515775
# Epoch [109] FLLoss: 0.005182 CELoss: 0.513487
# Epoch [110] FLLoss: 0.004918 CELoss: 0.504488
# Epoch [111] FLLoss: 0.005056 CELoss: 0.508753
# Epoch [112] FLLoss: 0.004917 CELoss: 0.498483
# Epoch [113] FLLoss: 0.005018 CELoss: 0.505758
# Epoch [114] FLLoss: 0.005037 CELoss: 0.503351
# Epoch [115] FLLoss: 0.005072 CELoss: 0.503563
# Epoch [116] FLLoss: 0.004865 CELoss: 0.489713
# Epoch [117] FLLoss: 0.005030 CELoss: 0.498214
# Epoch [118] FLLoss: 0.004965 CELoss: 0.504391
# Epoch [119] FLLoss: 0.004993 CELoss: 0.499821
# Epoch [120] FLLoss: 0.004856 CELoss: 0.497809
# Epoch [121] FLLoss: 0.004827 CELoss: 0.494234
# Epoch [122] FLLoss: 0.005040 CELoss: 0.506735
# Epoch [123] FLLoss: 0.005022 CELoss: 0.505671
# Epoch [124] FLLoss: 0.004986 CELoss: 0.501563
# Epoch [125] FLLoss: 0.004929 CELoss: 0.503569
# Epoch [126] FLLoss: 0.004946 CELoss: 0.504891
# Epoch [127] FLLoss: 0.004974 CELoss: 0.502287
# Epoch [128] FLLoss: 0.004830 CELoss: 0.497482
# Epoch [129] FLLoss: 0.004894 CELoss: 0.494960
# Epoch [130] FLLoss: 0.005128 CELoss: 0.512397
# Epoch [131] FLLoss: 0.005212 CELoss: 0.506561
# Epoch [132] FLLoss: 0.004859 CELoss: 0.496463
# Epoch [133] FLLoss: 0.004861 CELoss: 0.495568
# Epoch [134] FLLoss: 0.004892 CELoss: 0.501133
# Epoch [135] FLLoss: 0.004854 CELoss: 0.498676
# Epoch [136] FLLoss: 0.004797 CELoss: 0.488518
# Epoch [137] FLLoss: 0.004952 CELoss: 0.494519
# Epoch [138] FLLoss: 0.004900 CELoss: 0.490098
# Epoch [139] FLLoss: 0.004802 CELoss: 0.495810
# Epoch [140] FLLoss: 0.004855 CELoss: 0.495664
# Epoch [141] FLLoss: 0.004907 CELoss: 0.494681
# Epoch [142] FLLoss: 0.004912 CELoss: 0.498743
# Epoch [143] FLLoss: 0.004760 CELoss: 0.488262
# Epoch [144] FLLoss: 0.004742 CELoss: 0.493101
# Epoch [145] FLLoss: 0.004763 CELoss: 0.491460
# Epoch [146] FLLoss: 0.004739 CELoss: 0.487556
# Epoch [147] FLLoss: 0.004837 CELoss: 0.495834
# Epoch [148] FLLoss: 0.004806 CELoss: 0.490166
# Epoch [149] FLLoss: 0.004943 CELoss: 0.497378
# Epoch [150] FLLoss: 0.004818 CELoss: 0.492578
# Epoch [151] FLLoss: 0.004808 CELoss: 0.490311
# Epoch [152] FLLoss: 0.004898 CELoss: 0.495173
# Epoch [153] FLLoss: 0.004623 CELoss: 0.483041
# Epoch [154] FLLoss: 0.004686 CELoss: 0.486001
# Epoch [155] FLLoss: 0.004673 CELoss: 0.487166
# Epoch [156] FLLoss: 0.004805 CELoss: 0.482579
# Epoch [157] FLLoss: 0.004828 CELoss: 0.488715
# Epoch [158] FLLoss: 0.004726 CELoss: 0.489085
# Epoch [159] FLLoss: 0.004712 CELoss: 0.484965
# Epoch [160] FLLoss: 0.004908 CELoss: 0.498086
# Epoch [161] FLLoss: 0.004747 CELoss: 0.487525
# Epoch [162] FLLoss: 0.004758 CELoss: 0.488141
# Epoch [163] FLLoss: 0.004740 CELoss: 0.487773
# Epoch [164] FLLoss: 0.004615 CELoss: 0.475952
# Epoch [165] FLLoss: 0.004850 CELoss: 0.483376
# Epoch [166] FLLoss: 0.004778 CELoss: 0.491756
# Epoch [167] FLLoss: 0.004827 CELoss: 0.490056
# Epoch [168] FLLoss: 0.004748 CELoss: 0.490170
# Epoch [169] FLLoss: 0.004825 CELoss: 0.490892
# Epoch [170] FLLoss: 0.004584 CELoss: 0.482161
# Epoch [171] FLLoss: 0.004431 CELoss: 0.473383
# Epoch [172] FLLoss: 0.004772 CELoss: 0.483540
# Epoch [173] FLLoss: 0.004634 CELoss: 0.485635
# Epoch [174] FLLoss: 0.004543 CELoss: 0.471930
# Epoch [175] FLLoss: 0.004699 CELoss: 0.483800
# Epoch [176] FLLoss: 0.004712 CELoss: 0.486495
# Epoch [177] FLLoss: 0.004667 CELoss: 0.483034
# Epoch [178] FLLoss: 0.004686 CELoss: 0.481488
# Epoch [179] FLLoss: 0.004610 CELoss: 0.484491
# Epoch [180] FLLoss: 0.004623 CELoss: 0.475263
# Epoch [181] FLLoss: 0.004728 CELoss: 0.486260
# Epoch [182] FLLoss: 0.004719 CELoss: 0.483704
# Epoch [183] FLLoss: 0.004554 CELoss: 0.482508
# Epoch [184] FLLoss: 0.004710 CELoss: 0.480516
# Epoch [185] FLLoss: 0.004533 CELoss: 0.474295
# Epoch [186] FLLoss: 0.004655 CELoss: 0.473015
# Epoch [187] FLLoss: 0.004723 CELoss: 0.481121
# Epoch [188] FLLoss: 0.004651 CELoss: 0.477746
# Epoch [189] FLLoss: 0.004552 CELoss: 0.474255
# Epoch [190] FLLoss: 0.004524 CELoss: 0.467965
# Epoch [191] FLLoss: 0.004699 CELoss: 0.481848
# Epoch [192] FLLoss: 0.004567 CELoss: 0.477715
# Epoch [193] FLLoss: 0.004586 CELoss: 0.476668
# Epoch [194] FLLoss: 0.004698 CELoss: 0.475228
# Epoch [195] FLLoss: 0.004524 CELoss: 0.472954
# Epoch [196] FLLoss: 0.004726 CELoss: 0.480603
# Epoch [197] FLLoss: 0.004619 CELoss: 0.476934
# Epoch [198] FLLoss: 0.004594 CELoss: 0.469700
# Epoch [199] FLLoss: 0.004436 CELoss: 0.465124
# Epoch [200] FLLoss: 0.004503 CELoss: 0.466353

# %%
#保存模型
torch.save(model.state_dict, "parameter\\FL_COM_CNN_cls9_b40c200")

# %%
import torch
from torch.utils.data import DataLoader
import numpy as np
 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
model.to(device) 
model.eval() 

#推理之前对模型分类器权重做归一化
model.classifier.head[-1].weight.data = F.normalize(model.classifier.head[-1].weight.data, p=2, dim=1)
 
# 存储真实标签和预测结果 
all_labels = [] 
all_logits = [] 
 
# 假设dataset是PyTorch Dataset对象 
dataloader = DataLoader(test_set, batch_size=32, shuffle=False)

with torch.no_grad():
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        
        all_logits.append(outputs.cpu())
        all_labels.append(labels.cpu())

# 合并结果
y_true = torch.cat(all_labels).numpy()          # 形状 [n_samples]
logits = torch.cat(all_logits).numpy()          # 形状 [n_samples, 9]
y_pred = logits.argmax(axis=1)                  # 预测类别 [n_samples]
y_probs = torch.softmax(torch.tensor(logits), dim=1).numpy()  # 概率 [n_samples, 9]

print((y_pred==0).any())
# Out:
# True

# %%
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    classification_report, roc_auc_score
)

# 基础指标
print(f"FL 准确率: {accuracy_score(y_true, y_pred):.4f}")
print(f"FL 宏平均ROC AUC: {roc_auc_score(y_true, y_probs, multi_class='ovr'):.4f}")

# 分类报告（显示每个类别的精确率/召回率/F1）
print("\nFL 分类报告:")
print(classification_report(y_true, y_pred, target_names=[f"类{i}" for i in range(9)]))
# Out:
# FL 准确率: 0.5474
# FL 宏平均ROC AUC: 0.8524
#
# FL 分类报告:
#               precision    recall  f1-score   support
#
#           类0       0.91      0.70      0.79      5759
#           类1       0.23      0.33      0.27       734
#           类2       0.37      0.40      0.38       739
#           类3       0.35      0.42      0.38       728
#           类4       0.41      0.45      0.43       736
#           类5       0.27      0.36      0.31       733
#           类6       0.34      0.38      0.36       727
#           类7       0.31      0.43      0.36       736
#           类8       0.35      0.44      0.39       733
#
#     accuracy                           0.55     11625
#    macro avg       0.39      0.43      0.41     11625
# weighted avg       0.62      0.55      0.57     11625

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay


# 混淆矩阵
cm = confusion_matrix(y_true, y_pred, normalize="true")
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[f"class {i}" for i in range(9)]
)
fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, cmap='Reds', values_format='.2f')
plt.xticks(rotation=45)
plt.tight_layout()
plt.title("FL")
#plt.savefig('confusion_matrix.png', dpi=300)
plt.show()

# %%
# 计算每个类别的ROC AUC（One-vs-Rest）
from sklearn.preprocessing import label_binarize

# 将标签转换为二值形式
y_true_bin = label_binarize(y_true, classes=range(8))

# 计算每个类别的AUC
for i in range(8):
    auc = roc_auc_score(y_true_bin[:, i], y_probs[:, i])
    print(f"类{i}的ROC AUC: {auc:.4f}")
# Out:
# 类0的ROC AUC: 0.9291
# 类1的ROC AUC: 0.7765
# 类2的ROC AUC: 0.8581
# 类3的ROC AUC: 0.8620
# 类4的ROC AUC: 0.8735
# 类5的ROC AUC: 0.8175
# 类6的ROC AUC: 0.8509
# 类7的ROC AUC: 0.8406

# %%
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'orange']

# 为每个类别绘制ROC曲线
for i in range(8):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i],
             label=f'class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('CE muti class ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, cohen_kappa_score, matthews_corrcoef

def calculate_imbalanced_metrics(y_true, y_pred, y_probs):
    """
    计算类不平衡分类任务的综合评估指标
    
    参数：
        y_true: 真实标签 [n_samples]
        y_pred: 预测标签 [n_samples]
        y_probs: 各类别概率 [n_samples, 9]
    
    返回：
        包含各项指标的字典
    """
    metrics = {}
    
    # 基础分类报告（包含precision/recall/f1的macro和weighted平均）
    report = classification_report(
        y_true, y_pred,
        target_names=[f'cls{i}' for i in range(9)],
        output_dict=True
    )
    
    # 将分类报告整合到指标字典
    metrics.update({
        'macro_precision': report['macro avg']['precision'],
        'macro_recall': report['macro avg']['recall'],
        'macro_f1': report['macro avg']['f1-score'],
        'weighted_precision': report['weighted avg']['precision'],
        'weighted_recall': report['weighted avg']['recall'],
        'weighted_f1': report['weighted avg']['f1-score'],
        'accuracy': report['accuracy']
    })
    
    # 混淆矩阵相关指标
    cm = confusion_matrix(y_true, y_pred)
    metrics['confusion_matrix'] = cm
    
    # 平衡准确率（各类别召回率的平均）
    metrics['balanced_accuracy'] = np.mean([cm[i,i]/cm[i,:].sum() for i in range(9)])
    
    # 多类别AUC（One-vs-Rest方法）
    try:
        metrics['roc_auc_ovr_macro'] = roc_auc_score(
            y_true, y_probs, 
            multi_class='ovr', 
            average='macro'
        )
        metrics['roc_auc_ovr_weighted'] = roc_auc_score(
            y_true, y_probs,
            multi_class='ovr',
            average='weighted'
        )
    except Exception as e:
        print(f"AUC计算异常: {str(e)}")
        metrics.update({'roc_auc_ovr_macro': None, 'roc_auc_ovr_weighted': None})
    
    # Cohen's Kappa
    metrics['cohens_kappa'] = cohen_kappa_score(y_true, y_pred)
    
    # 马修斯相关系数（MCC）
    metrics['mcc'] = matthews_corrcoef(y_true, y_pred)
    
    # 类别分布统计
    class_distribution = np.bincount(y_true, minlength=9)
    metrics.update({
        'class_distribution': class_distribution,
        'imbalance_ratio': class_distribution.max() / class_distribution.min()
    })
    
    return metrics

# 使用示例
metrics = calculate_imbalanced_metrics(y_true, y_pred, y_probs)

# 打印关键指标
print(f"【关键指标】")
print(f"宏平均F1: {metrics['macro_f1']:.4f}")
print(f"加权F1: {metrics['weighted_f1']:.4f}")
print(f"平衡准确率: {metrics['balanced_accuracy']:.4f}")
print(f"AUC-OVR宏平均: {metrics['roc_auc_ovr_macro']:.4f}")
print(f"马修斯相关系数: {metrics['mcc']:.4f}")
print(f"类别不平衡比: {metrics['imbalance_ratio']:.1f}:1")

# 输出混淆矩阵（可视化建议）
print("\n【混淆矩阵样例】")
print(metrics['confusion_matrix'])  # 显示前3x3部分
# Out:
# 【关键指标】
# 宏平均F1: 0.4096
# 加权F1: 0.5710
# 平衡准确率: 0.4394
# AUC-OVR宏平均: 0.8558
# 马修斯相关系数: 0.4199
# 类别不平衡比: 7.9:1
#
# 【混淆矩阵样例】
# [[3907  323  220  210  136  304  265  188  206]
#  [  49  228   33  134   42   80   65   54   49]
#  [  57   68  280   28  158   62   23   39   24]
#  [  34   88   20  334   59   18   31   74   70]
#  [  33   50  125   75  344   12   18   33   46]
#  [  47   74   43   39   19  316   48  120   27]
#  [  38   64   17   39   20   52  295   30  172]
#  [  27   61   28   80   38  154   24  284   40]
#  [  29   50    8   72   28   28  160   37  321]]
